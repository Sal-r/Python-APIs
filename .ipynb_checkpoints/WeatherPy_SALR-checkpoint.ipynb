# %%
#dependencies & Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from weather_api_SALR import weather_api_SALR

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Generate Cities List
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
#url for api call
api_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_SALR

#city data list

cities_data = []


#print start of api call
print('Starting API Call')
print('-----------------')

#counters for number of cities

group_count = 1
add_count = 1

for city in cities:
    
    time.sleep(1.2)
    
    if (group_count % 50 == 0) and (group_count >= 50):
        
        add_count += 1
        group_count = 0
        
    #url for every city
    
    cities_url = api_url + '&q=' + city
    
    print('API record set %s # %s | %s' % (add_count, group_count, city))
    
    #new group number
    group_count += 1
    
    try:

        cities_weather = requests.get(cities_url).json()
    
        cities_clouds = cities_weather["clouds"]["all"]
        cities_country = cities_weather["sys"]["country"]
        city_date = cities_weather["dt"]
        cities_high_temp = cities_weather["main"]["temp_max"]
        cities_humidity = cities_weather["main"]["humidity"]
        cities_latitude = cities_weather["coord"]["lat"]
        cities_longitude = cities_weather["coord"]["lon"]
        cities_wind = cities_weather["wind"]["speed"]

        cities_data.append({'city': city,
                            'clouds': cities_clouds,
                            'country': cities_country,
                            'date': city_date,
                            'high_temp': cities_high_temp,
                            'humidity': cities_humidity,
                            'latitude': cities_latitude,
                            'longitude': cities_longitude,
                            'wind': cities_wind})
        
        print(cities_country)

    except:
        print('Error. City data not found. Next city. . .')
        pass

#api call done
print('---------------------' + '\n' + '| Finished API Call |' + '\n' + '---------------------')
# Out:
# Starting API Call
# -----------------
# API record set 1 # 1 | lebu
# CL
# API record set 1 # 2 | biltine
# TD
# API record set 1 # 3 | saldanha
# ZA
# API record set 1 # 4 | illoqqortoormiut
# Error. City data not found. Next city. . .
# API record set 1 # 5 | vaini
# TO
# API record set 1 # 6 | havre-saint-pierre
# CA
# API record set 1 # 7 | jamestown
# US
# API record set 1 # 8 | mataura
# NZ
# API record set 1 # 9 | bethel
# US
# API record set 1 # 10 | bambous virieux
# MU
# API record set 1 # 11 | isangel
# VU
# API record set 1 # 12 | punta arenas
# CL
# API record set 1 # 13 | hilo
# US
# API record set 1 # 14 | miharu
# JP
# API record set 1 # 15 | kapaa
# US
# API record set 1 # 16 | albany
# US
# API record set 1 # 17 | pimentel
# PE
# API record set 1 # 18 | plettenberg bay
# ZA
# API record set 1 # 19 | vila franca do campo
# PT
# API record set 1 # 20 | pirovskoye
# RU
# API record set 1 # 21 | andenes
# NO
# API record set 1 # 22 | ushuaia
# AR
# API record set 1 # 23 | akdepe
# TM
# API record set 1 # 24 | barrow
# US
# API record set 1 # 25 | groningen
# NL
# API record set 1 # 26 | victoria
# HK
# API record set 1 # 27 | qaanaaq
# GL
# API record set 1 # 28 | georgetown
# MY
# API record set 1 # 29 | piedade
# BR
# API record set 1 # 30 | bengkulu
# ID
# API record set 1 # 31 | clyde river
# CA
# API record set 1 # 32 | kailua
# US
# API record set 1 # 33 | kodiak
# US
# API record set 1 # 34 | lagoa
# PT
# API record set 1 # 35 | rikitea
# PF
# API record set 1 # 36 | mar del plata
# AR
# API record set 1 # 37 | nizhneyansk
# Error. City data not found. Next city. . .
# API record set 1 # 38 | iquique
# CL
# API record set 1 # 39 | quatre cocos
# MU
# API record set 1 # 40 | vestmannaeyjar
# IS
# API record set 1 # 41 | yellowknife
# CA
# API record set 1 # 42 | cape town
# ZA
# API record set 1 # 43 | fortuna
# US
# API record set 1 # 44 | provideniya
# RU
# API record set 1 # 45 | cururupu
# BR
# API record set 1 # 46 | tsihombe
# Error. City data not found. Next city. . .
# API record set 1 # 47 | mys shmidta
# Error. City data not found. Next city. . .
# API record set 1 # 48 | bluff
# NZ
# API record set 1 # 49 | chicama
# PE
# API record set 2 # 0 | acarau
# BR
# API record set 2 # 1 | ponta do sol
# PT
# API record set 2 # 2 | la primavera
# CO
# API record set 2 # 3 | torbay
# CA
# API record set 2 # 4 | spas
# UA
# API record set 2 # 5 | sao joao da barra
# BR
# API record set 2 # 6 | quanzhou
# CN
# API record set 2 # 7 | castro
# BR
# API record set 2 # 8 | zharkent
# KZ
# API record set 2 # 9 | thunder bay
# CA
# API record set 2 # 10 | swift current
# CA
# API record set 2 # 11 | henties bay
# NA
# API record set 2 # 12 | san patricio
# MX
# API record set 2 # 13 | cabo san lucas
# MX
# API record set 2 # 14 | la rioja
# ES
# API record set 2 # 15 | taolanaro
# Error. City data not found. Next city. . .
# API record set 2 # 16 | portland
# US
# API record set 2 # 17 | calbuco
# CL
# API record set 2 # 18 | nhulunbuy
# AU
# API record set 2 # 19 | te anau
# NZ
# API record set 2 # 20 | palauig
# PH
# API record set 2 # 21 | blagoyevo
# RU
# API record set 2 # 22 | englewood
# US
# API record set 2 # 23 | isa khel
# AF
# API record set 2 # 24 | port elizabeth
# ZA
# API record set 2 # 25 | port lincoln
# AU
# API record set 2 # 26 | hecun
# CN
# API record set 2 # 27 | adrar
# MR
# API record set 2 # 28 | atotonilco el grande
# MX
# API record set 2 # 29 | caravelas
# BR
# API record set 2 # 30 | busselton
# AU
# API record set 2 # 31 | victoria point
# AU
# API record set 2 # 32 | hermanus
# ZA
# API record set 2 # 33 | coquimbo
# CL
# API record set 2 # 34 | port hardy
# CA
# API record set 2 # 35 | faya
# SA
# API record set 2 # 36 | pacifica
# US
# API record set 2 # 37 | attawapiskat
# Error. City data not found. Next city. . .
# API record set 2 # 38 | palabuhanratu
# Error. City data not found. Next city. . .
# API record set 2 # 39 | rovaniemi
# FI
# API record set 2 # 40 | yerbogachen
# RU
# API record set 2 # 41 | hun
# LY
# API record set 2 # 42 | kedrovyy
# RU
# API record set 2 # 43 | seoul
# KR
# API record set 2 # 44 | komsomolskiy
# UZ
# API record set 2 # 45 | makakilo city
# US
# API record set 2 # 46 | port blair
# IN
# API record set 2 # 47 | ribeira grande
# PT
# API record set 2 # 48 | san fernando
# PH
# API record set 2 # 49 | amderma
# Error. City data not found. Next city. . .
# API record set 3 # 0 | new castle
# US
# API record set 3 # 1 | chuy
# UY
# API record set 3 # 2 | novyy urengoy
# RU
# API record set 3 # 3 | bathsheba
# BB
# API record set 3 # 4 | yining
# CN
# API record set 3 # 5 | belushya guba
# Error. City data not found. Next city. . .
# API record set 3 # 6 | atuona
# PF
# API record set 3 # 7 | ust-omchug
# RU
# API record set 3 # 8 | kaitangata
# NZ
# API record set 3 # 9 | zhuzhou
# CN
# API record set 3 # 10 | cacoal
# BR
# API record set 3 # 11 | brockville
# CA
# API record set 3 # 12 | alofi
# NU
# API record set 3 # 13 | nishihara
# JP
# API record set 3 # 14 | tessalit
# ML
# API record set 3 # 15 | port alfred
# ZA
# API record set 3 # 16 | omboue
# GA
# API record set 3 # 17 | tacna
# PE
# API record set 3 # 18 | saskylakh
# RU
# API record set 3 # 19 | antofagasta
# CL
# API record set 3 # 20 | dargaville
# NZ
# API record set 3 # 21 | umzimvubu
# Error. City data not found. Next city. . .
# API record set 3 # 22 | labuhan
# ID
# API record set 3 # 23 | mayo
# US
# API record set 3 # 24 | nelson bay
# AU
# API record set 3 # 25 | aykhal
# RU
# API record set 3 # 26 | anar darreh
# Error. City data not found. Next city. . .
# API record set 3 # 27 | grand river south east
# Error. City data not found. Next city. . .
# API record set 3 # 28 | ambon
# ID
# API record set 3 # 29 | fairbanks
# US
# API record set 3 # 30 | saint-philippe
# RE
# API record set 3 # 31 | cidreira
# BR
# API record set 3 # 32 | hervey bay
# AU
# API record set 3 # 33 | cherskiy
# RU
# API record set 3 # 34 | rosario do sul
# BR
# API record set 3 # 35 | carnarvon
# AU
# API record set 3 # 36 | talnakh
# RU
# API record set 3 # 37 | east london
# ZA
# API record set 3 # 38 | gamba
# GA
# API record set 3 # 39 | hobart
# AU
# API record set 3 # 40 | mount isa
# AU
# API record set 3 # 41 | todos santos
# MX
# API record set 3 # 42 | ola
# RU
# API record set 3 # 43 | namibe
# AO
# API record set 3 # 44 | gua musang
# MY
# API record set 3 # 45 | kamenka
# RU
# API record set 3 # 46 | severo-kurilsk
# RU
# API record set 3 # 47 | bari sadri
# IN
# API record set 3 # 48 | szendro
# HU
# API record set 3 # 49 | san quintin
# MX
# API record set 4 # 0 | sibi
# PK
# API record set 4 # 1 | bredasdorp
# ZA
# API record set 4 # 2 | payo
# ID
# API record set 4 # 3 | andros town
# BS
# API record set 4 # 4 | nueva concepcion
# GT
# API record set 4 # 5 | harbour breton
# CA
# API record set 4 # 6 | saleaula
# Error. City data not found. Next city. . .
# API record set 4 # 7 | nanortalik
# GL
# API record set 4 # 8 | purepero
# MX
# API record set 4 # 9 | shar
# KZ
# API record set 4 # 10 | klaksvik
# FO
# API record set 4 # 11 | macaboboni
# Error. City data not found. Next city. . .
# API record set 4 # 12 | marabba
# SD
# API record set 4 # 13 | okha
# RU
# API record set 4 # 14 | ilo
# PE
# API record set 4 # 15 | tampa
# US
# API record set 4 # 16 | cockburn town
# TC
# API record set 4 # 17 | ancud
# CL
# API record set 4 # 18 | whitehorse
# CA
# API record set 4 # 19 | narsaq
# GL
# API record set 4 # 20 | thinadhoo
# MV
# API record set 4 # 21 | sechura
# PE
# API record set 4 # 22 | jilmah
# Error. City data not found. Next city. . .
# API record set 4 # 23 | atar
# MR
# API record set 4 # 24 | mahebourg
# MU
# API record set 4 # 25 | pacific grove
# US
# API record set 4 # 26 | dikson
# RU
# API record set 4 # 27 | cervo
# ES
# API record set 4 # 28 | tiksi
# RU
# API record set 4 # 29 | mazagao
# BR
# API record set 4 # 30 | sioux lookout
# CA
# API record set 4 # 31 | krasnoselkup
# RU
# API record set 4 # 32 | constitucion
# CL
# API record set 4 # 33 | gusau
# NG
# API record set 4 # 34 | kruisfontein
# ZA
# API record set 4 # 35 | sibolga
# ID
# API record set 4 # 36 | jinzhou
# CN
# API record set 4 # 37 | santa maria
# BR
# API record set 4 # 38 | poronaysk
# RU
# API record set 4 # 39 | kijang
# KR
# API record set 4 # 40 | avera
# US
# API record set 4 # 41 | vardo
# NO
# API record set 4 # 42 | mumford
# GH
# API record set 4 # 43 | hami
# CN
# API record set 4 # 44 | la ronge
# CA
# API record set 4 # 45 | sentyabrskiy
# Error. City data not found. Next city. . .
# API record set 4 # 46 | lima
# PE
# API record set 4 # 47 | nyurba
# RU
# API record set 4 # 48 | new norfolk
# AU
# API record set 4 # 49 | caala
# AO
# API record set 5 # 0 | guanica
# PR
# API record set 5 # 1 | sao felix do xingu
# BR
# API record set 5 # 2 | tuktoyaktuk
# CA
# API record set 5 # 3 | nikolskoye
# RU
# API record set 5 # 4 | avarua
# CK
# API record set 5 # 5 | arraial do cabo
# BR
# API record set 5 # 6 | husavik
# IS
# API record set 5 # 7 | pangkalanbuun
# ID
# API record set 5 # 8 | axim
# GH
# API record set 5 # 9 | kazachinskoye
# RU
# API record set 5 # 10 | airai
# TL
# API record set 5 # 11 | ketchikan
# US
# API record set 5 # 12 | hithadhoo
# MV
# API record set 5 # 13 | misratah
# LY
# API record set 5 # 14 | nalut
# LY
# API record set 5 # 15 | katima mulilo
# NA
# API record set 5 # 16 | belaya gora
# RU
# API record set 5 # 17 | tabialan
# Error. City data not found. Next city. . .
# API record set 5 # 18 | hualmay
# PE
# API record set 5 # 19 | ostrovnoy
# RU
# API record set 5 # 20 | goundam
# ML
# API record set 5 # 21 | lorengau
# PG
# API record set 5 # 22 | sinnamary
# GF
# API record set 5 # 23 | chernyshevskiy
# RU
# API record set 5 # 24 | huangpi
# CN
# API record set 5 # 25 | ljubinje
# BA
# API record set 5 # 26 | margate
# GB
# API record set 5 # 27 | martinsville
# US
# API record set 5 # 28 | rustenburg
# ZA
# API record set 5 # 29 | barentsburg
# Error. City data not found. Next city. . .
# API record set 5 # 30 | yar-sale
# RU
# API record set 5 # 31 | puerto ayora
# EC
# API record set 5 # 32 | kavaratti
# IN
# API record set 5 # 33 | businga
# CD
# API record set 5 # 34 | hofn
# IS
# API record set 5 # 35 | tete
# MZ
# API record set 5 # 36 | mao
# ES
# API record set 5 # 37 | betare oya
# CM
# API record set 5 # 38 | khatanga
# RU
# API record set 5 # 39 | puyang
# CN
# API record set 5 # 40 | puerto colombia
# CO
# API record set 5 # 41 | washington
# US
# API record set 5 # 42 | vaitupu
# Error. City data not found. Next city. . .
# API record set 5 # 43 | sept-iles
# CA
# API record set 5 # 44 | havoysund
# NO
# API record set 5 # 45 | acajutiba
# BR
# API record set 5 # 46 | mansa
# IN
# API record set 5 # 47 | altagracia de orituco
# VE
# API record set 5 # 48 | kambove
# CD
# API record set 5 # 49 | estelle
# US
# API record set 6 # 0 | inhambane
# MZ
# API record set 6 # 1 | livenka
# RU
# API record set 6 # 2 | kincardine
# GB
# API record set 6 # 3 | gat
# IL
# API record set 6 # 4 | agadir
# MA
# API record set 6 # 5 | lander
# US
# API record set 6 # 6 | saquarema
# BR
# API record set 6 # 7 | mildura
# AU
# API record set 6 # 8 | sagua de tanamo
# CU
# API record set 6 # 9 | bosaso
# SO
# API record set 6 # 10 | iqaluit
# CA
# API record set 6 # 11 | carahue
# CL
# API record set 6 # 12 | poyarkovo
# RU
# API record set 6 # 13 | houma
# US
# API record set 6 # 14 | kapit
# MY
# API record set 6 # 15 | camacha
# PT
# API record set 6 # 16 | mantua
# IT
# API record set 6 # 17 | jacareacanga
# BR
# API record set 6 # 18 | phan thiet
# VN
# API record set 6 # 19 | katha
# Error. City data not found. Next city. . .
# API record set 6 # 20 | kaoma
# ZM
# API record set 6 # 21 | hibbing
# US
# API record set 6 # 22 | bulawayo
# ZW
# API record set 6 # 23 | tiarei
# PF
# API record set 6 # 24 | tasiilaq
# GL
# API record set 6 # 25 | egvekinot
# RU
# API record set 6 # 26 | karamea
# Error. City data not found. Next city. . .
# API record set 6 # 27 | la peca
# PE
# API record set 6 # 28 | montepuez
# MZ
# API record set 6 # 29 | chokurdakh
# RU
# API record set 6 # 30 | limoeiro
# BR
# API record set 6 # 31 | high level
# CA
# API record set 6 # 32 | xuddur
# SO
# API record set 6 # 33 | tumannyy
# Error. City data not found. Next city. . .
# API record set 6 # 34 | pevek
# RU
# API record set 6 # 35 | hambantota
# LK
# API record set 6 # 36 | ranong
# TH
# API record set 6 # 37 | sanmenxia
# CN
# API record set 6 # 38 | lata
# PT
# API record set 6 # 39 | niquero
# CU
# API record set 6 # 40 | berkovica
# BA
# API record set 6 # 41 | valle hermoso
# MX
# API record set 6 # 42 | general roca
# AR
# API record set 6 # 43 | porto novo
# BJ
# API record set 6 # 44 | hanna
# CA
# API record set 6 # 45 | hamilton
# US
# API record set 6 # 46 | samusu
# Error. City data not found. Next city. . .
# API record set 6 # 47 | dubovka
# RU
# API record set 6 # 48 | semey
# KZ
# API record set 6 # 49 | grand-santi
# GF
# API record set 7 # 0 | mbanza-ngungu
# CD
# API record set 7 # 1 | college
# US
# API record set 7 # 2 | north platte
# US
# API record set 7 # 3 | mount gambier
# AU
# API record set 7 # 4 | souillac
# MU
# API record set 7 # 5 | butaritari
# KI
# API record set 7 # 6 | codrington
# AU
# API record set 7 # 7 | chancay
# PE
# API record set 7 # 8 | tateyama
# JP
# API record set 7 # 9 | ijaki
# Error. City data not found. Next city. . .
# API record set 7 # 10 | bull savanna
# JM
# API record set 7 # 11 | vagay
# RU
# API record set 7 # 12 | arlit
# NE
# API record set 7 # 13 | nome
# US
# API record set 7 # 14 | longyearbyen
# SJ
# API record set 7 # 15 | ucluelet
# CA
# API record set 7 # 16 | halalo
# Error. City data not found. Next city. . .
# API record set 7 # 17 | peniche
# PT
# API record set 7 # 18 | pathein
# MM
# API record set 7 # 19 | lavrentiya
# RU
# API record set 7 # 20 | skjervoy
# NO
# API record set 7 # 21 | barra patuca
# HN
# API record set 7 # 22 | leningradskiy
# RU
# API record set 7 # 23 | kopervik
# NO
# API record set 7 # 24 | nola
# IT
# API record set 7 # 25 | gonzalez
# US
# API record set 7 # 26 | samandag
# TR
# API record set 7 # 27 | praia da vitoria
# PT
# API record set 7 # 28 | bongandanga
# CD
# API record set 7 # 29 | morales
# CO
# API record set 7 # 30 | alto baudo
# Error. City data not found. Next city. . .
# API record set 7 # 31 | puerto leguizamo
# CO
# API record set 7 # 32 | lacey
# US
# API record set 7 # 33 | kang
# BW
# API record set 7 # 34 | shimoda
# JP
# API record set 7 # 35 | sitka
# US
# API record set 7 # 36 | moron
# AR
# API record set 7 # 37 | korla
# CN
# API record set 7 # 38 | dunedin
# NZ
# API record set 7 # 39 | douglas
# US
# API record set 7 # 40 | dieppe
# FR
# API record set 7 # 41 | upernavik
# GL
# API record set 7 # 42 | roma
# US
# API record set 7 # 43 | bada
# RU
# API record set 7 # 44 | noyabrsk
# RU
# API record set 7 # 45 | palaikastron
# GR
# API record set 7 # 46 | nabire
# ID
# API record set 7 # 47 | lenger
# KZ
# API record set 7 # 48 | ukiah
# US
# API record set 7 # 49 | mehamn
# NO
# API record set 8 # 0 | fort nelson
# CA
# API record set 8 # 1 | pontianak
# ID
# API record set 8 # 2 | muhos
# FI
# API record set 8 # 3 | karaul
# Error. City data not found. Next city. . .
# API record set 8 # 4 | ilulissat
# GL
# API record set 8 # 5 | olafsvik
# IS
# API record set 8 # 6 | dongsheng
# CN
# API record set 8 # 7 | teguldet
# RU
# API record set 8 # 8 | bahia honda
# CU
# API record set 8 # 9 | troitsko-pechorsk
# RU
# API record set 8 # 10 | gawler
# AU
# API record set 8 # 11 | fare
# PF
# API record set 8 # 12 | bud
# US
# API record set 8 # 13 | muisne
# EC
# API record set 8 # 14 | dayong
# CN
# API record set 8 # 15 | cap malheureux
# MU
# API record set 8 # 16 | taganak
# PH
# API record set 8 # 17 | totma
# RU
# API record set 8 # 18 | jibuti
# DJ
# API record set 8 # 19 | swellendam
# ZA
# API record set 8 # 20 | nortelandia
# BR
# API record set 8 # 21 | altay
# CN
# API record set 8 # 22 | khandbari
# NP
# API record set 8 # 23 | innisfail
# AU
# API record set 8 # 24 | sao filipe
# CV
# API record set 8 # 25 | zhigansk
# RU
# API record set 8 # 26 | socorro
# US
# API record set 8 # 27 | qianan
# CN
# API record set 8 # 28 | chimoio
# MZ
# API record set 8 # 29 | prince george
# CA
# API record set 8 # 30 | shima
# CN
# API record set 8 # 31 | kegayli
# Error. City data not found. Next city. . .
# API record set 8 # 32 | kerman
# IR
# API record set 8 # 33 | gardez
# AF
# API record set 8 # 34 | thompson
# CA
# API record set 8 # 35 | zaragoza
# ES
# API record set 8 # 36 | gisenyi
# RW
# API record set 8 # 37 | yulara
# AU
# API record set 8 # 38 | darnah
# LY
# API record set 8 # 39 | richards bay
# ZA
# API record set 8 # 40 | faanui
# PF
# API record set 8 # 41 | emerald
# AU
# API record set 8 # 42 | anshun
# CN
# API record set 8 # 43 | buala
# SB
# API record set 8 # 44 | paso de los toros
# UY
# API record set 8 # 45 | ayan
# RU
# API record set 8 # 46 | inyonga
# TZ
# API record set 8 # 47 | manzhouli
# CN
# API record set 8 # 48 | boyolangu
# ID
# API record set 8 # 49 | shimla
# IN
# API record set 9 # 0 | otjimbingwe
# NA
# API record set 9 # 1 | abalak
# RU
# API record set 9 # 2 | lewistown
# US
# API record set 9 # 3 | bowmore
# US
# API record set 9 # 4 | xicotencatl
# MX
# API record set 9 # 5 | road town
# VG
# API record set 9 # 6 | port-gentil
# GA
# API record set 9 # 7 | gallup
# US
# API record set 9 # 8 | tura
# IN
# API record set 9 # 9 | buraydah
# SA
# API record set 9 # 10 | oranjestad
# AW
# API record set 9 # 11 | seguela
# CI
# API record set 9 # 12 | nouadhibou
# MR
# API record set 9 # 13 | arman
# RU
# API record set 9 # 14 | kavieng
# PG
# API record set 9 # 15 | waddan
# LY
# API record set 9 # 16 | bassar
# TG
# API record set 9 # 17 | cartagena
# CO
# API record set 9 # 18 | gorlice
# PL
# API record set 9 # 19 | funadhoo
# MV
# API record set 9 # 20 | male
# MV
# API record set 9 # 21 | okhotsk
# RU
# API record set 9 # 22 | champerico
# GT
# API record set 9 # 23 | meulaboh
# ID
# API record set 9 # 24 | rafai
# CF
# API record set 9 # 25 | itoman
# JP
# API record set 9 # 26 | pierre
# US
# API record set 9 # 27 | sompeta
# IN
# API record set 9 # 28 | voznesenye
# RU
# API record set 9 # 29 | camopi
# GF
# API record set 9 # 30 | athabasca
# CA
# API record set 9 # 31 | hindaun
# IN
# API record set 9 # 32 | itacare
# BR
# API record set 9 # 33 | katobu
# ID
# API record set 9 # 34 | tautira
# PF
# API record set 9 # 35 | salalah
# OM
# API record set 9 # 36 | saint george
# US
# API record set 9 # 37 | karwar
# IN
# API record set 9 # 38 | padang
# ID
# API record set 9 # 39 | kupang
# ID
# API record set 9 # 40 | goryachegorsk
# RU
# API record set 9 # 41 | taunggyi
# MM
# API record set 9 # 42 | filimonovo
# RU
# API record set 9 # 43 | cinco esquinas
# CR
# API record set 9 # 44 | uvira
# CD
# API record set 9 # 45 | grenfell
# AU
# API record set 9 # 46 | irbeyskoye
# RU
# API record set 9 # 47 | bousso
# TD
# API record set 9 # 48 | jawhar
# SO
# API record set 9 # 49 | deogarh
# IN
# API record set 10 # 0 | lakes entrance
# AU
# API record set 10 # 1 | jefferson city
# US
# API record set 10 # 2 | brandon
# US
# API record set 10 # 3 | darhan
# MN
# API record set 10 # 4 | bullhead city
# US
# API record set 10 # 5 | moiyabana
# Error. City data not found. Next city. . .
# API record set 10 # 6 | jiazi
# CN
# API record set 10 # 7 | zyryanka
# RU
# API record set 10 # 8 | campo gobierno
# MX
# API record set 10 # 9 | norman wells
# CA
# API record set 10 # 10 | ikole
# Error. City data not found. Next city. . .
# API record set 10 # 11 | elko
# US
# API record set 10 # 12 | banos
# EC
# API record set 10 # 13 | dingle
# PH
# API record set 10 # 14 | middle island
# US
# API record set 10 # 15 | surt
# LY
# API record set 10 # 16 | villa union
# MX
# API record set 10 # 17 | sarakhs
# IR
# API record set 10 # 18 | port lavaca
# US
# API record set 10 # 19 | amahai
# ID
# API record set 10 # 20 | coihaique
# CL
# API record set 10 # 21 | kosice
# SK
# API record set 10 # 22 | amguri
# IN
# API record set 10 # 23 | hazorasp
# UZ
# API record set 10 # 24 | shuangcheng
# CN
# API record set 10 # 25 | tuatapere
# NZ
# API record set 10 # 26 | tilichiki
# RU
# API record set 10 # 27 | verkhnevilyuysk
# RU
# API record set 10 # 28 | luderitz
# NA
# API record set 10 # 29 | merauke
# ID
# API record set 10 # 30 | watertown
# US
# API record set 10 # 31 | broome
# US
# API record set 10 # 32 | sibutad
# PH
# API record set 10 # 33 | kuche
# Error. City data not found. Next city. . .
# API record set 10 # 34 | ugep
# NG
# API record set 10 # 35 | esperance
# AU
# API record set 10 # 36 | marcona
# Error. City data not found. Next city. . .
# API record set 10 # 37 | mrirt
# Error. City data not found. Next city. . .
# API record set 10 # 38 | grand centre
# Error. City data not found. Next city. . .
# API record set 10 # 39 | taltal
# CL
# API record set 10 # 40 | olga
# RU
# API record set 10 # 41 | tevriz
# RU
# API record set 10 # 42 | barentu
# ER
# API record set 10 # 43 | sete
# FR
# API record set 10 # 44 | riyadh
# SA
# API record set 10 # 45 | kalabo
# ZM
# API record set 10 # 46 | khonuu
# Error. City data not found. Next city. . .
# API record set 10 # 47 | indramayu
# ID
# API record set 10 # 48 | sabha
# LY
# API record set 10 # 49 | sur
# OM
# API record set 11 # 0 | manokwari
# ID
# API record set 11 # 1 | nemuro
# JP
# API record set 11 # 2 | doctor pedro p. pena
# Error. City data not found. Next city. . .
# API record set 11 # 3 | touros
# BR
# API record set 11 # 4 | sembakung
# ID
# API record set 11 # 5 | san cristobal
# VE
# API record set 11 # 6 | pisco
# PE
# API record set 11 # 7 | oktyabrskiy
# RU
# API record set 11 # 8 | half moon bay
# US
# API record set 11 # 9 | katsuura
# JP
# API record set 11 # 10 | sangar
# RU
# API record set 11 # 11 | tabuk
# PH
# API record set 11 # 12 | lockhart
# US
# API record set 11 # 13 | salinopolis
# BR
# API record set 11 # 14 | ostrowiec swietokrzyski
# PL
# API record set 11 # 15 | albanel
# CA
# API record set 11 # 16 | bujaru
# BR
# API record set 11 # 17 | magadan
# RU
# API record set 11 # 18 | qandala
# SO
# API record set 11 # 19 | point fortin
# TT
# API record set 11 # 20 | pacasmayo
# PE
# API record set 11 # 21 | grootfontein
# NA
# API record set 11 # 22 | kahului
# US
# API record set 11 # 23 | jinchang
# CN
# API record set 11 # 24 | milingimbi
# Error. City data not found. Next city. . .
# API record set 11 # 25 | balkhash
# KZ
# API record set 11 # 26 | labuan
# MY
# API record set 11 # 27 | sorland
# NO
# API record set 11 # 28 | hanzhong
# CN
# API record set 11 # 29 | vostok
# RU
# API record set 11 # 30 | pangnirtung
# CA
# API record set 11 # 31 | xai-xai
# MZ
# API record set 11 # 32 | nuevo progreso
# MX
# API record set 11 # 33 | jumla
# NP
# API record set 11 # 34 | tromso
# NO
# API record set 11 # 35 | baculin
# PH
# API record set 11 # 36 | warmbad
# NA
# API record set 11 # 37 | ulladulla
# AU
# API record set 11 # 38 | stykkisholmur
# IS
# API record set 11 # 39 | joshimath
# IN
# API record set 11 # 40 | vitim
# RU
# API record set 11 # 41 | antananarivo
# MG
# API record set 11 # 42 | talavera de la reina
# ES
# API record set 11 # 43 | namatanai
# PG
# API record set 11 # 44 | salisbury
# GB
# API record set 11 # 45 | shasta lake
# US
# API record set 11 # 46 | changping
# CN
# API record set 11 # 47 | beringovskiy
# RU
# API record set 11 # 48 | ramshir
# IR
# API record set 11 # 49 | kondinskoye
# RU
# API record set 12 # 0 | alvorada
# BR
# API record set 12 # 1 | isiro
# CD
# API record set 12 # 2 | ampanihy
# MG
# API record set 12 # 3 | atherton
# GB
# API record set 12 # 4 | bokoro
# TD
# API record set 12 # 5 | nogliki
# RU
# API record set 12 # 6 | mahina
# PF
# API record set 12 # 7 | abashiri
# JP
# API record set 12 # 8 | selcuk
# TR
# API record set 12 # 9 | maceio
# BR
# API record set 12 # 10 | cascais
# PT
# API record set 12 # 11 | castelo
# BR
# API record set 12 # 12 | rondonopolis
# BR
# API record set 12 # 13 | jalu
# LY
# API record set 12 # 14 | mathbaria
# BD
# API record set 12 # 15 | saravan
# AM
# API record set 12 # 16 | klyuchi
# RU
# API record set 12 # 17 | bay roberts
# CA
# API record set 12 # 18 | nieuw nickerie
# SR
# API record set 12 # 19 | vega de alatorre
# MX
# API record set 12 # 20 | mareeba
# AU
# API record set 12 # 21 | komsomolsk
# UA
# API record set 12 # 22 | caxito
# AO
# API record set 12 # 23 | nguiu
# Error. City data not found. Next city. . .
# API record set 12 # 24 | samarai
# PG
# API record set 12 # 25 | kenai
# US
# API record set 12 # 26 | kinsale
# IE
# API record set 12 # 27 | sirur
# IN
# API record set 12 # 28 | panaba
# MX
# API record set 12 # 29 | potsdam
# DE
# API record set 12 # 30 | maralal
# KE
# API record set 12 # 31 | batsfjord
# NO
# API record set 12 # 32 | lerwick
# GB
# API record set 12 # 33 | asau
# RO
# API record set 12 # 34 | labrea
# BR
# API record set 12 # 35 | suntar
# RU
# API record set 12 # 36 | svetlogorsk
# BY
# API record set 12 # 37 | ambunti
# PG
# API record set 12 # 38 | sopo
# CO
# API record set 12 # 39 | severomuysk
# RU
# API record set 12 # 40 | the valley
# AI
# API record set 12 # 41 | kattivakkam
# IN
# API record set 12 # 42 | gornopravdinsk
# RU
# API record set 12 # 43 | raahe
# FI
# API record set 12 # 44 | roald
# NO
# API record set 12 # 45 | pilar
# BR
# API record set 12 # 46 | koumac
# NC
# API record set 12 # 47 | petropavlovsk-kamchatskiy
# RU
# API record set 12 # 48 | brae
# GB
# API record set 12 # 49 | guisa
# CU
# API record set 13 # 0 | launceston
# AU
# API record set 13 # 1 | kununurra
# AU
# API record set 13 # 2 | mersing
# MY
# API record set 13 # 3 | darovskoy
# RU
# API record set 13 # 4 | kaeo
# NZ
# API record set 13 # 5 | rulenge
# TZ
# API record set 13 # 6 | vao
# NC
# API record set 13 # 7 | wilmington
# US
# API record set 13 # 8 | hasanabad
# IR
# API record set 13 # 9 | bajo baudo
# Error. City data not found. Next city. . .
# API record set 13 # 10 | bilibino
# RU
# API record set 13 # 11 | smithers
# CA
# API record set 13 # 12 | de aar
# ZA
# API record set 13 # 13 | willmar
# US
# API record set 13 # 14 | paine
# CL
# API record set 13 # 15 | tawkar
# Error. City data not found. Next city. . .
# API record set 13 # 16 | raudeberg
# NO
# API record set 13 # 17 | lasa
# IT
# API record set 13 # 18 | savannah bight
# HN
# API record set 13 # 19 | geraldton
# AU
# API record set 13 # 20 | pochutla
# MX
# API record set 13 # 21 | vallenar
# CL
# API record set 13 # 22 | nantucket
# US
# API record set 13 # 23 | sola
# VU
# API record set 13 # 24 | villa carlos paz
# AR
# ---------------------
# | Finished API Call |
# ---------------------

# %%
cities_data
# Out:
# [{'city': 'lebu',
#   'clouds': 0,
#   'country': 'CL',
#   'date': 1586056262,
#   'high_temp': 54.43,
#   'humidity': 75,
#   'latitude': -37.62,
#   'longitude': -73.65,
#   'wind': 14.79},
#  {'city': 'biltine',
#   'clouds': 97,
#   'country': 'TD',
#   'date': 1586056264,
#   'high_temp': 84,
#   'humidity': 13,
#   'latitude': 14.53,
#   'longitude': 20.92,
#   'wind': 8.61},
#  {'city': 'saldanha',
#   'clouds': 81,
#   'country': 'ZA',
#   'date': 1586056265,
#   'high_temp': 57.2,
#   'humidity': 93,
#   'latitude': -33.01,
#   'longitude': 17.94,
#   'wind': 6.93},
#  {'city': 'vaini',
#   'clouds': 75,
#   'country': 'TO',
#   'date': 1586056267,
#   'high_temp': 78.8,
#   'humidity': 69,
#   'latitude': -21.2,
#   'longitude': -175.2,
#   'wind': 8.05},
#  {'city': 'havre-saint-pierre',
#   'clouds': 90,
#   'country': 'CA',
#   'date': 1586056269,
#   'high_temp': 30.2,
#   'humidity': 92,
#   'latitude': 50.23,
#   'longitude': -63.6,
#   'wind': 2.24},
#  {'city': 'jamestown',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056270,
#   'high_temp': 48.2,
#   'humidity': 75,
#   'latitude': 42.1,
#   'longitude': -79.24,
#   'wind': 0.81},
#  {'city': 'mataura',
#   'clouds': 97,
#   'country': 'NZ',
#   'date': 1586056271,
#   'high_temp': 69.01,
#   'humidity': 56,
#   'latitude': -46.19,
#   'longitude': 168.86,
#   'wind': 5.01},
#  {'city': 'bethel',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056273,
#   'high_temp': 52,
#   'humidity': 61,
#   'latitude': 41.37,
#   'longitude': -73.41,
#   'wind': 4.43},
#  {'city': 'bambous virieux',
#   'clouds': 40,
#   'country': 'MU',
#   'date': 1586056274,
#   'high_temp': 77,
#   'humidity': 78,
#   'latitude': -20.34,
#   'longitude': 57.76,
#   'wind': 3.36},
#  {'city': 'isangel',
#   'clouds': 90,
#   'country': 'VU',
#   'date': 1586056275,
#   'high_temp': 84.2,
#   'humidity': 79,
#   'latitude': -19.55,
#   'longitude': 169.27,
#   'wind': 11.41},
#  {'city': 'punta arenas',
#   'clouds': 75,
#   'country': 'CL',
#   'date': 1586056276,
#   'high_temp': 41,
#   'humidity': 86,
#   'latitude': -53.15,
#   'longitude': -70.92,
#   'wind': 31.09},
#  {'city': 'hilo',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056119,
#   'high_temp': 78.8,
#   'humidity': 74,
#   'latitude': 19.73,
#   'longitude': -155.09,
#   'wind': 11.41},
#  {'city': 'miharu',
#   'clouds': 75,
#   'country': 'JP',
#   'date': 1586056279,
#   'high_temp': 46,
#   'humidity': 100,
#   'latitude': 37.43,
#   'longitude': 140.48,
#   'wind': 14.99},
#  {'city': 'kapaa',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586056261,
#   'high_temp': 80.6,
#   'humidity': 78,
#   'latitude': 22.08,
#   'longitude': -159.32,
#   'wind': 12.75},
#  {'city': 'albany',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586056203,
#   'high_temp': 53.6,
#   'humidity': 66,
#   'latitude': 42.6,
#   'longitude': -73.97,
#   'wind': 5.82},
#  {'city': 'pimentel',
#   'clouds': 14,
#   'country': 'PE',
#   'date': 1586056283,
#   'high_temp': 72.97,
#   'humidity': 78,
#   'latitude': -6.84,
#   'longitude': -79.93,
#   'wind': 10.13},
#  {'city': 'plettenberg bay',
#   'clouds': 22,
#   'country': 'ZA',
#   'date': 1586056284,
#   'high_temp': 63.57,
#   'humidity': 73,
#   'latitude': -34.05,
#   'longitude': 23.37,
#   'wind': 4.68},
#  {'city': 'vila franca do campo',
#   'clouds': 40,
#   'country': 'PT',
#   'date': 1586056108,
#   'high_temp': 59,
#   'humidity': 82,
#   'latitude': 37.72,
#   'longitude': -25.43,
#   'wind': 4.7},
#  {'city': 'pirovskoye',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056286,
#   'high_temp': 34.7,
#   'humidity': 81,
#   'latitude': 57.63,
#   'longitude': 92.27,
#   'wind': 4.83},
#  {'city': 'andenes',
#   'clouds': 74,
#   'country': 'NO',
#   'date': 1586056288,
#   'high_temp': 26.6,
#   'humidity': 53,
#   'latitude': 69.31,
#   'longitude': 16.12,
#   'wind': 16.11},
#  {'city': 'ushuaia',
#   'clouds': 20,
#   'country': 'AR',
#   'date': 1586056028,
#   'high_temp': 39.2,
#   'humidity': 86,
#   'latitude': -54.8,
#   'longitude': -68.3,
#   'wind': 9.17},
#  {'city': 'akdepe',
#   'clouds': 23,
#   'country': 'TM',
#   'date': 1586056290,
#   'high_temp': 48.2,
#   'humidity': 76,
#   'latitude': 42.06,
#   'longitude': 59.38,
#   'wind': 6.93},
#  {'city': 'barrow',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056081,
#   'high_temp': 17.6,
#   'humidity': 78,
#   'latitude': 71.29,
#   'longitude': -156.79,
#   'wind': 12.75},
#  {'city': 'groningen',
#   'clouds': 32,
#   'country': 'NL',
#   'date': 1586056293,
#   'high_temp': 42.8,
#   'humidity': 69,
#   'latitude': 53.25,
#   'longitude': 6.75,
#   'wind': 5.82},
#  {'city': 'victoria',
#   'clouds': 40,
#   'country': 'HK',
#   'date': 1586056201,
#   'high_temp': 66,
#   'humidity': 88,
#   'latitude': 22.29,
#   'longitude': 114.16,
#   'wind': 10.29},
#  {'city': 'qaanaaq',
#   'clouds': 100,
#   'country': 'GL',
#   'date': 1586056296,
#   'high_temp': 12.31,
#   'humidity': 77,
#   'latitude': 77.48,
#   'longitude': -69.36,
#   'wind': 6.89},
#  {'city': 'georgetown',
#   'clouds': 20,
#   'country': 'MY',
#   'date': 1586056297,
#   'high_temp': 86,
#   'humidity': 79,
#   'latitude': 5.41,
#   'longitude': 100.34,
#   'wind': 4.7},
#  {'city': 'piedade',
#   'clouds': 30,
#   'country': 'BR',
#   'date': 1586056298,
#   'high_temp': 64.99,
#   'humidity': 83,
#   'latitude': -23.71,
#   'longitude': -47.43,
#   'wind': 4.25},
#  {'city': 'bengkulu',
#   'clouds': 100,
#   'country': 'ID',
#   'date': 1586056290,
#   'high_temp': 79.86,
#   'humidity': 79,
#   'latitude': -3.8,
#   'longitude': 102.27,
#   'wind': 2.19},
#  {'city': 'clyde river',
#   'clouds': 1,
#   'country': 'CA',
#   'date': 1586056301,
#   'high_temp': 3.2,
#   'humidity': 84,
#   'latitude': 70.47,
#   'longitude': -68.59,
#   'wind': 21.92},
#  {'city': 'kailua',
#   'clouds': 20,
#   'country': 'US',
#   'date': 1586056303,
#   'high_temp': 82.4,
#   'humidity': 69,
#   'latitude': 21.4,
#   'longitude': -157.74,
#   'wind': 9.17},
#  {'city': 'kodiak',
#   'clouds': 20,
#   'country': 'US',
#   'date': 1586056120,
#   'high_temp': 55.4,
#   'humidity': 30,
#   'latitude': 57.79,
#   'longitude': -152.41,
#   'wind': 3.36},
#  {'city': 'lagoa',
#   'clouds': 17,
#   'country': 'PT',
#   'date': 1586056305,
#   'high_temp': 57.9,
#   'humidity': 74,
#   'latitude': 39.05,
#   'longitude': -27.98,
#   'wind': 10.51},
#  {'city': 'rikitea',
#   'clouds': 8,
#   'country': 'PF',
#   'date': 1586056306,
#   'high_temp': 75.63,
#   'humidity': 77,
#   'latitude': -23.12,
#   'longitude': -134.97,
#   'wind': 18.41},
#  {'city': 'mar del plata',
#   'clouds': 5,
#   'country': 'AR',
#   'date': 1586056308,
#   'high_temp': 64,
#   'humidity': 93,
#   'latitude': -38,
#   'longitude': -57.56,
#   'wind': 7},
#  {'city': 'iquique',
#   'clouds': 90,
#   'country': 'CL',
#   'date': 1586056017,
#   'high_temp': 71.6,
#   'humidity': 68,
#   'latitude': -20.22,
#   'longitude': -70.14,
#   'wind': 3.36},
#  {'city': 'quatre cocos',
#   'clouds': 40,
#   'country': 'MU',
#   'date': 1586056311,
#   'high_temp': 77,
#   'humidity': 78,
#   'latitude': -20.21,
#   'longitude': 57.76,
#   'wind': 3.36},
#  {'city': 'vestmannaeyjar',
#   'clouds': 100,
#   'country': 'IS',
#   'date': 1586056313,
#   'high_temp': 28.89,
#   'humidity': 96,
#   'latitude': 63.44,
#   'longitude': -20.27,
#   'wind': 19.91},
#  {'city': 'yellowknife',
#   'clouds': 20,
#   'country': 'CA',
#   'date': 1586056315,
#   'high_temp': 14,
#   'humidity': 51,
#   'latitude': 62.46,
#   'longitude': -114.35,
#   'wind': 6.31},
#  {'city': 'cape town',
#   'clouds': 99,
#   'country': 'ZA',
#   'date': 1586056140,
#   'high_temp': 60.8,
#   'humidity': 100,
#   'latitude': -33.93,
#   'longitude': 18.42,
#   'wind': 5.82},
#  {'city': 'fortuna',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056112,
#   'high_temp': 53.01,
#   'humidity': 87,
#   'latitude': 40.6,
#   'longitude': -124.16,
#   'wind': 10.29},
#  {'city': 'provideniya',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056318,
#   'high_temp': 15.01,
#   'humidity': 94,
#   'latitude': 64.38,
#   'longitude': -173.3,
#   'wind': 20.78},
#  {'city': 'cururupu',
#   'clouds': 100,
#   'country': 'BR',
#   'date': 1586056320,
#   'high_temp': 77.76,
#   'humidity': 91,
#   'latitude': -1.83,
#   'longitude': -44.87,
#   'wind': 4.43},
#  {'city': 'bluff',
#   'clouds': 100,
#   'country': 'NZ',
#   'date': 1586056323,
#   'high_temp': 69.01,
#   'humidity': 56,
#   'latitude': -46.6,
#   'longitude': 168.33,
#   'wind': 5.01},
#  {'city': 'chicama',
#   'clouds': 27,
#   'country': 'PE',
#   'date': 1586056325,
#   'high_temp': 74.52,
#   'humidity': 70,
#   'latitude': -7.84,
#   'longitude': -79.15,
#   'wind': 5.06},
#  {'city': 'acarau',
#   'clouds': 97,
#   'country': 'BR',
#   'date': 1586056326,
#   'high_temp': 77.23,
#   'humidity': 91,
#   'latitude': -2.89,
#   'longitude': -40.12,
#   'wind': 4.14},
#  {'city': 'ponta do sol',
#   'clouds': 75,
#   'country': 'PT',
#   'date': 1586056327,
#   'high_temp': 66.2,
#   'humidity': 77,
#   'latitude': 32.67,
#   'longitude': -17.1,
#   'wind': 4.7},
#  {'city': 'la primavera',
#   'clouds': 88,
#   'country': 'CO',
#   'date': 1586056329,
#   'high_temp': 81.25,
#   'humidity': 73,
#   'latitude': 5.49,
#   'longitude': -70.41,
#   'wind': 4.9},
#  {'city': 'torbay',
#   'clouds': 90,
#   'country': 'CA',
#   'date': 1586056330,
#   'high_temp': 28.99,
#   'humidity': 92,
#   'latitude': 47.67,
#   'longitude': -52.73,
#   'wind': 8.05},
#  {'city': 'spas',
#   'clouds': 20,
#   'country': 'UA',
#   'date': 1586056331,
#   'high_temp': 33.73,
#   'humidity': 75,
#   'latitude': 48.89,
#   'longitude': 24.06,
#   'wind': 1.99},
#  {'city': 'sao joao da barra',
#   'clouds': 74,
#   'country': 'BR',
#   'date': 1586056332,
#   'high_temp': 73.83,
#   'humidity': 76,
#   'latitude': -21.64,
#   'longitude': -41.05,
#   'wind': 10.27},
#  {'city': 'quanzhou',
#   'clouds': 75,
#   'country': 'CN',
#   'date': 1586056334,
#   'high_temp': 62.6,
#   'humidity': 51,
#   'latitude': 24.91,
#   'longitude': 118.59,
#   'wind': 6.71},
#  {'city': 'castro',
#   'clouds': 0,
#   'country': 'BR',
#   'date': 1586056335,
#   'high_temp': 54.61,
#   'humidity': 61,
#   'latitude': -24.79,
#   'longitude': -50.01,
#   'wind': 3.58},
#  {'city': 'zharkent',
#   'clouds': 0,
#   'country': 'KZ',
#   'date': 1586056336,
#   'high_temp': 60.03,
#   'humidity': 28,
#   'latitude': 44.16,
#   'longitude': 80,
#   'wind': 6.42},
#  {'city': 'thunder bay',
#   'clouds': 5,
#   'country': 'CA',
#   'date': 1586056338,
#   'high_temp': 30.2,
#   'humidity': 63,
#   'latitude': 48.4,
#   'longitude': -89.32,
#   'wind': 2.24},
#  {'city': 'swift current',
#   'clouds': 90,
#   'country': 'CA',
#   'date': 1586056339,
#   'high_temp': 19.4,
#   'humidity': 92,
#   'latitude': 50.28,
#   'longitude': -107.8,
#   'wind': 12.75},
#  {'city': 'henties bay',
#   'clouds': 13,
#   'country': 'NA',
#   'date': 1586056340,
#   'high_temp': 60.01,
#   'humidity': 93,
#   'latitude': -22.12,
#   'longitude': 14.28,
#   'wind': 3.31},
#  {'city': 'san patricio',
#   'clouds': 40,
#   'country': 'MX',
#   'date': 1586056123,
#   'high_temp': 75.2,
#   'humidity': 78,
#   'latitude': 19.22,
#   'longitude': -104.7,
#   'wind': 11.41},
#  {'city': 'cabo san lucas',
#   'clouds': 75,
#   'country': 'MX',
#   'date': 1586056343,
#   'high_temp': 72,
#   'humidity': 56,
#   'latitude': 22.89,
#   'longitude': -109.91,
#   'wind': 2.24},
#  {'city': 'la rioja',
#   'clouds': 100,
#   'country': 'ES',
#   'date': 1586056344,
#   'high_temp': 48.2,
#   'humidity': 87,
#   'latitude': 42.25,
#   'longitude': -2.5,
#   'wind': 11.41},
#  {'city': 'portland',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056292,
#   'high_temp': 46.99,
#   'humidity': 87,
#   'latitude': 45.52,
#   'longitude': -122.68,
#   'wind': 2.13},
#  {'city': 'calbuco',
#   'clouds': 90,
#   'country': 'CL',
#   'date': 1586056348,
#   'high_temp': 48.2,
#   'humidity': 87,
#   'latitude': -41.77,
#   'longitude': -73.13,
#   'wind': 3.36},
#  {'city': 'nhulunbuy',
#   'clouds': 40,
#   'country': 'AU',
#   'date': 1586056349,
#   'high_temp': 87.8,
#   'humidity': 62,
#   'latitude': -12.23,
#   'longitude': 136.77,
#   'wind': 11.41},
#  {'city': 'te anau',
#   'clouds': 100,
#   'country': 'NZ',
#   'date': 1586056351,
#   'high_temp': 63.07,
#   'humidity': 55,
#   'latitude': -45.42,
#   'longitude': 167.72,
#   'wind': 6.4},
#  {'city': 'palauig',
#   'clouds': 8,
#   'country': 'PH',
#   'date': 1586056352,
#   'high_temp': 88.59,
#   'humidity': 52,
#   'latitude': 15.44,
#   'longitude': 119.9,
#   'wind': 8.25},
#  {'city': 'blagoyevo',
#   'clouds': 84,
#   'country': 'RU',
#   'date': 1586056354,
#   'high_temp': 22.64,
#   'humidity': 95,
#   'latitude': 63.37,
#   'longitude': 47.92,
#   'wind': 7.47},
#  {'city': 'englewood',
#   'clouds': 20,
#   'country': 'US',
#   'date': 1586056355,
#   'high_temp': 52,
#   'humidity': 52,
#   'latitude': 39.65,
#   'longitude': -104.99,
#   'wind': 11.41},
#  {'city': 'isa khel',
#   'clouds': 100,
#   'country': 'AF',
#   'date': 1586056356,
#   'high_temp': 65.86,
#   'humidity': 48,
#   'latitude': 36.67,
#   'longitude': 68.84,
#   'wind': 2.44},
#  {'city': 'port elizabeth',
#   'clouds': 75,
#   'country': 'ZA',
#   'date': 1586056357,
#   'high_temp': 64.4,
#   'humidity': 93,
#   'latitude': -33.92,
#   'longitude': 25.57,
#   'wind': 23.04},
#  {'city': 'port lincoln',
#   'clouds': 88,
#   'country': 'AU',
#   'date': 1586056359,
#   'high_temp': 63.64,
#   'humidity': 67,
#   'latitude': -34.73,
#   'longitude': 135.87,
#   'wind': 17.67},
#  {'city': 'hecun',
#   'clouds': 100,
#   'country': 'CN',
#   'date': 1586056360,
#   'high_temp': 61.92,
#   'humidity': 28,
#   'latitude': 36.53,
#   'longitude': 114.11,
#   'wind': 6.53},
#  {'city': 'adrar',
#   'clouds': 0,
#   'country': 'MR',
#   'date': 1586056362,
#   'high_temp': 71.69,
#   'humidity': 20,
#   'latitude': 20.5,
#   'longitude': -10.07,
#   'wind': 9.91},
#  {'city': 'atotonilco el grande',
#   'clouds': 82,
#   'country': 'MX',
#   'date': 1586056363,
#   'high_temp': 65.93,
#   'humidity': 38,
#   'latitude': 20.28,
#   'longitude': -98.67,
#   'wind': 3.67},
#  {'city': 'caravelas',
#   'clouds': 99,
#   'country': 'BR',
#   'date': 1586056364,
#   'high_temp': 78.75,
#   'humidity': 83,
#   'latitude': -17.71,
#   'longitude': -39.25,
#   'wind': 12.57},
#  {'city': 'busselton',
#   'clouds': 100,
#   'country': 'AU',
#   'date': 1586056091,
#   'high_temp': 66.99,
#   'humidity': 43,
#   'latitude': -33.65,
#   'longitude': 115.33,
#   'wind': 10.09},
#  {'city': 'victoria point',
#   'clouds': 20,
#   'country': 'AU',
#   'date': 1586056367,
#   'high_temp': 87.01,
#   'humidity': 39,
#   'latitude': -27.58,
#   'longitude': 153.3,
#   'wind': 8.05},
#  {'city': 'hermanus',
#   'clouds': 99,
#   'country': 'ZA',
#   'date': 1586056368,
#   'high_temp': 60.01,
#   'humidity': 92,
#   'latitude': -34.42,
#   'longitude': 19.23,
#   'wind': 3},
#  {'city': 'coquimbo',
#   'clouds': 100,
#   'country': 'CL',
#   'date': 1586056369,
#   'high_temp': 59,
#   'humidity': 87,
#   'latitude': -29.95,
#   'longitude': -71.34,
#   'wind': 3.36},
#  {'city': 'port hardy',
#   'clouds': 75,
#   'country': 'CA',
#   'date': 1586056371,
#   'high_temp': 42.8,
#   'humidity': 60,
#   'latitude': 50.7,
#   'longitude': -127.42,
#   'wind': 12.75},
#  {'city': 'faya',
#   'clouds': 8,
#   'country': 'SA',
#   'date': 1586056373,
#   'high_temp': 60.8,
#   'humidity': 76,
#   'latitude': 18.39,
#   'longitude': 42.45,
#   'wind': 3.67},
#  {'city': 'pacifica',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056374,
#   'high_temp': 55.99,
#   'humidity': 93,
#   'latitude': 37.61,
#   'longitude': -122.49,
#   'wind': 11.41},
#  {'city': 'rovaniemi',
#   'clouds': 16,
#   'country': 'FI',
#   'date': 1586056247,
#   'high_temp': 15.8,
#   'humidity': 66,
#   'latitude': 66.5,
#   'longitude': 25.72,
#   'wind': 4.7},
#  {'city': 'yerbogachen',
#   'clouds': 86,
#   'country': 'RU',
#   'date': 1586056379,
#   'high_temp': 30.61,
#   'humidity': 87,
#   'latitude': 61.28,
#   'longitude': 108.01,
#   'wind': 13.91},
#  {'city': 'hun',
#   'clouds': 0,
#   'country': 'LY',
#   'date': 1586056380,
#   'high_temp': 54.41,
#   'humidity': 73,
#   'latitude': 29.13,
#   'longitude': 15.95,
#   'wind': 5.55},
#  {'city': 'kedrovyy',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056382,
#   'high_temp': 35.6,
#   'humidity': 47,
#   'latitude': 56.17,
#   'longitude': 91.82,
#   'wind': 6.71},
#  {'city': 'seoul',
#   'clouds': 1,
#   'country': 'KR',
#   'date': 1586056109,
#   'high_temp': 50,
#   'humidity': 18,
#   'latitude': 37.57,
#   'longitude': 126.98,
#   'wind': 6.93},
#  {'city': 'komsomolskiy',
#   'clouds': 67,
#   'country': 'UZ',
#   'date': 1586056384,
#   'high_temp': 59,
#   'humidity': 62,
#   'latitude': 40.43,
#   'longitude': 71.72,
#   'wind': 4.7},
#  {'city': 'makakilo city',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056386,
#   'high_temp': 82.4,
#   'humidity': 88,
#   'latitude': 21.35,
#   'longitude': -158.09,
#   'wind': 8.05},
#  {'city': 'port blair',
#   'clouds': 1,
#   'country': 'IN',
#   'date': 1586056387,
#   'high_temp': 82.67,
#   'humidity': 69,
#   'latitude': 11.67,
#   'longitude': 92.75,
#   'wind': 9.89},
#  {'city': 'ribeira grande',
#   'clouds': 14,
#   'country': 'PT',
#   'date': 1586056388,
#   'high_temp': 58.51,
#   'humidity': 76,
#   'latitude': 38.52,
#   'longitude': -28.7,
#   'wind': 9.24},
#  {'city': 'san fernando',
#   'clouds': 40,
#   'country': 'PH',
#   'date': 1586056390,
#   'high_temp': 89.6,
#   'humidity': 52,
#   'latitude': 15.03,
#   'longitude': 120.69,
#   'wind': 4.7},
#  {'city': 'new castle',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056392,
#   'high_temp': 54,
#   'humidity': 62,
#   'latitude': 41,
#   'longitude': -80.35,
#   'wind': 3.36},
#  {'city': 'chuy',
#   'clouds': 0,
#   'country': 'UY',
#   'date': 1586056394,
#   'high_temp': 62.62,
#   'humidity': 77,
#   'latitude': -33.7,
#   'longitude': -53.46,
#   'wind': 6.98},
#  {'city': 'novyy urengoy',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056396,
#   'high_temp': 34.39,
#   'humidity': 96,
#   'latitude': 66.08,
#   'longitude': 76.63,
#   'wind': 17.16},
#  {'city': 'bathsheba',
#   'clouds': 20,
#   'country': 'BB',
#   'date': 1586056098,
#   'high_temp': 78.8,
#   'humidity': 83,
#   'latitude': 13.22,
#   'longitude': -59.52,
#   'wind': 12.75},
#  {'city': 'yining',
#   'clouds': 100,
#   'country': 'CN',
#   'date': 1586056398,
#   'high_temp': 59.88,
#   'humidity': 64,
#   'latitude': 29.04,
#   'longitude': 114.56,
#   'wind': 3.42},
#  {'city': 'atuona',
#   'clouds': 18,
#   'country': 'PF',
#   'date': 1586056401,
#   'high_temp': 82.11,
#   'humidity': 74,
#   'latitude': -9.8,
#   'longitude': -139.03,
#   'wind': 13.42},
#  {'city': 'ust-omchug',
#   'clouds': 98,
#   'country': 'RU',
#   'date': 1586056402,
#   'high_temp': 16.54,
#   'humidity': 84,
#   'latitude': 61.15,
#   'longitude': 149.63,
#   'wind': 10.04},
#  {'city': 'kaitangata',
#   'clouds': 89,
#   'country': 'NZ',
#   'date': 1586056403,
#   'high_temp': 61,
#   'humidity': 76,
#   'latitude': -46.28,
#   'longitude': 169.85,
#   'wind': 1.99},
#  {'city': 'zhuzhou',
#   'clouds': 100,
#   'country': 'CN',
#   'date': 1586056405,
#   'high_temp': 60.8,
#   'humidity': 72,
#   'latitude': 27.83,
#   'longitude': 113.15,
#   'wind': 6.71},
#  {'city': 'cacoal',
#   'clouds': 87,
#   'country': 'BR',
#   'date': 1586056406,
#   'high_temp': 74.39,
#   'humidity': 88,
#   'latitude': -11.44,
#   'longitude': -61.45,
#   'wind': 2.91},
#  {'city': 'brockville',
#   'clouds': 90,
#   'country': 'CA',
#   'date': 1586056407,
#   'high_temp': 48.2,
#   'humidity': 81,
#   'latitude': 44.58,
#   'longitude': -75.68,
#   'wind': 6.93},
#  {'city': 'alofi',
#   'clouds': 100,
#   'country': 'NU',
#   'date': 1586056409,
#   'high_temp': 82.4,
#   'humidity': 74,
#   'latitude': -19.06,
#   'longitude': -169.92,
#   'wind': 11.41},
#  {'city': 'nishihara',
#   'clouds': 40,
#   'country': 'JP',
#   'date': 1586056410,
#   'high_temp': 71.6,
#   'humidity': 56,
#   'latitude': 26.18,
#   'longitude': 127.76,
#   'wind': 11.41},
#  {'city': 'tessalit',
#   'clouds': 0,
#   'country': 'ML',
#   'date': 1586056412,
#   'high_temp': 73.53,
#   'humidity': 14,
#   'latitude': 20.2,
#   'longitude': 1.01,
#   'wind': 4.88},
#  {'city': 'port alfred',
#   'clouds': 2,
#   'country': 'ZA',
#   'date': 1586056413,
#   'high_temp': 64.99,
#   'humidity': 93,
#   'latitude': -33.59,
#   'longitude': 26.89,
#   'wind': 5.99},
#  {'city': 'omboue',
#   'clouds': 100,
#   'country': 'GA',
#   'date': 1586056415,
#   'high_temp': 75.4,
#   'humidity': 93,
#   'latitude': -1.57,
#   'longitude': 9.26,
#   'wind': 6.11},
#  {'city': 'tacna',
#   'clouds': 97,
#   'country': 'PE',
#   'date': 1586056416,
#   'high_temp': 73.4,
#   'humidity': 60,
#   'latitude': -18.01,
#   'longitude': -70.25,
#   'wind': 2.24},
#  {'city': 'saskylakh',
#   'clouds': 54,
#   'country': 'RU',
#   'date': 1586056417,
#   'high_temp': 15.44,
#   'humidity': 94,
#   'latitude': 71.92,
#   'longitude': 114.08,
#   'wind': 13.02},
#  {'city': 'antofagasta',
#   'clouds': 38,
#   'country': 'CL',
#   'date': 1586056418,
#   'high_temp': 66.2,
#   'humidity': 77,
#   'latitude': -23.65,
#   'longitude': -70.4,
#   'wind': 2.24},
#  {'city': 'dargaville',
#   'clouds': 43,
#   'country': 'NZ',
#   'date': 1586056420,
#   'high_temp': 68.43,
#   'humidity': 53,
#   'latitude': -35.93,
#   'longitude': 173.88,
#   'wind': 10.16},
#  {'city': 'labuhan',
#   'clouds': 88,
#   'country': 'ID',
#   'date': 1586056422,
#   'high_temp': 86.49,
#   'humidity': 71,
#   'latitude': -6.88,
#   'longitude': 112.21,
#   'wind': 5.86},
#  {'city': 'mayo',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056424,
#   'high_temp': 54,
#   'humidity': 76,
#   'latitude': 38.89,
#   'longitude': -76.51,
#   'wind': 4.7},
#  {'city': 'nelson bay',
#   'clouds': 0,
#   'country': 'AU',
#   'date': 1586056425,
#   'high_temp': 75.99,
#   'humidity': 43,
#   'latitude': -32.72,
#   'longitude': 152.15,
#   'wind': 18.34},
#  {'city': 'aykhal',
#   'clouds': 90,
#   'country': 'RU',
#   'date': 1586056426,
#   'high_temp': 24.8,
#   'humidity': 79,
#   'latitude': 66,
#   'longitude': 111.5,
#   'wind': 11.18},
#  {'city': 'ambon',
#   'clouds': 40,
#   'country': 'ID',
#   'date': 1586056430,
#   'high_temp': 91.4,
#   'humidity': 63,
#   'latitude': -3.7,
#   'longitude': 128.18,
#   'wind': 5.82},
#  {'city': 'fairbanks',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056370,
#   'high_temp': 34,
#   'humidity': 100,
#   'latitude': 64.84,
#   'longitude': -147.72,
#   'wind': 3.36},
#  {'city': 'saint-philippe',
#   'clouds': 21,
#   'country': 'RE',
#   'date': 1586056433,
#   'high_temp': 73.4,
#   'humidity': 69,
#   'latitude': -21.36,
#   'longitude': 55.77,
#   'wind': 5.82},
#  {'city': 'cidreira',
#   'clouds': 0,
#   'country': 'BR',
#   'date': 1586056434,
#   'high_temp': 66.81,
#   'humidity': 71,
#   'latitude': -30.18,
#   'longitude': -50.21,
#   'wind': 6.53},
#  {'city': 'hervey bay',
#   'clouds': 40,
#   'country': 'AU',
#   'date': 1586056435,
#   'high_temp': 87.01,
#   'humidity': 61,
#   'latitude': -25.3,
#   'longitude': 152.85,
#   'wind': 8.05},
#  {'city': 'cherskiy',
#   'clouds': 49,
#   'country': 'RU',
#   'date': 1586056437,
#   'high_temp': 2.57,
#   'humidity': 89,
#   'latitude': 68.75,
#   'longitude': 161.3,
#   'wind': 5.39},
#  {'city': 'rosario do sul',
#   'clouds': 0,
#   'country': 'BR',
#   'date': 1586056438,
#   'high_temp': 60.28,
#   'humidity': 59,
#   'latitude': -30.26,
#   'longitude': -54.91,
#   'wind': 3.8},
#  {'city': 'carnarvon',
#   'clouds': 66,
#   'country': 'AU',
#   'date': 1586056439,
#   'high_temp': 80.6,
#   'humidity': 61,
#   'latitude': -24.87,
#   'longitude': 113.63,
#   'wind': 14.99},
#  {'city': 'talnakh',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056440,
#   'high_temp': 32,
#   'humidity': 92,
#   'latitude': 69.49,
#   'longitude': 88.4,
#   'wind': 26.84},
#  {'city': 'east london',
#   'clouds': 0,
#   'country': 'ZA',
#   'date': 1586056442,
#   'high_temp': 68,
#   'humidity': 68,
#   'latitude': -33.02,
#   'longitude': 27.91,
#   'wind': 6.93},
#  {'city': 'gamba',
#   'clouds': 100,
#   'country': 'GA',
#   'date': 1586056443,
#   'high_temp': 77.14,
#   'humidity': 87,
#   'latitude': -2.65,
#   'longitude': 10,
#   'wind': 1.28},
#  {'city': 'hobart',
#   'clouds': 75,
#   'country': 'AU',
#   'date': 1586056387,
#   'high_temp': 51.8,
#   'humidity': 53,
#   'latitude': -42.88,
#   'longitude': 147.33,
#   'wind': 19.46},
#  {'city': 'mount isa',
#   'clouds': 40,
#   'country': 'AU',
#   'date': 1586056445,
#   'high_temp': 80.6,
#   'humidity': 22,
#   'latitude': -20.73,
#   'longitude': 139.5,
#   'wind': 10.29},
#  {'city': 'todos santos',
#   'clouds': 75,
#   'country': 'MX',
#   'date': 1586056447,
#   'high_temp': 72,
#   'humidity': 49,
#   'latitude': 23.45,
#   'longitude': -110.22,
#   'wind': 3.24},
#  {'city': 'ola',
#   'clouds': 99,
#   'country': 'RU',
#   'date': 1586056448,
#   'high_temp': 20.1,
#   'humidity': 95,
#   'latitude': 59.58,
#   'longitude': 151.28,
#   'wind': 10.45},
#  {'city': 'namibe',
#   'clouds': 4,
#   'country': 'AO',
#   'date': 1586056450,
#   'high_temp': 72.46,
#   'humidity': 74,
#   'latitude': -15.2,
#   'longitude': 12.15,
#   'wind': 7.31},
#  {'city': 'gua musang',
#   'clouds': 5,
#   'country': 'MY',
#   'date': 1586056451,
#   'high_temp': 90.72,
#   'humidity': 50,
#   'latitude': 4.88,
#   'longitude': 101.96,
#   'wind': 1.88},
#  {'city': 'kamenka',
#   'clouds': 6,
#   'country': 'RU',
#   'date': 1586056453,
#   'high_temp': 34,
#   'humidity': 68,
#   'latitude': 51.32,
#   'longitude': 42.77,
#   'wind': 1.99},
#  {'city': 'severo-kurilsk',
#   'clouds': 45,
#   'country': 'RU',
#   'date': 1586056454,
#   'high_temp': 31.59,
#   'humidity': 91,
#   'latitude': 50.68,
#   'longitude': 156.12,
#   'wind': 5.3},
#  {'city': 'bari sadri',
#   'clouds': 9,
#   'country': 'IN',
#   'date': 1586056455,
#   'high_temp': 84,
#   'humidity': 14,
#   'latitude': 24.42,
#   'longitude': 74.47,
#   'wind': 7.05},
#  {'city': 'szendro',
#   'clouds': 0,
#   'country': 'HU',
#   'date': 1586056457,
#   'high_temp': 42.8,
#   'humidity': 41,
#   'latitude': 48.4,
#   'longitude': 20.73,
#   'wind': 12.75},
#  {'city': 'san quintin',
#   'clouds': 0,
#   'country': 'MX',
#   'date': 1586056458,
#   'high_temp': 58.32,
#   'humidity': 77,
#   'latitude': 30.48,
#   'longitude': -115.95,
#   'wind': 11.65},
#  {'city': 'sibi',
#   'clouds': 0,
#   'country': 'PK',
#   'date': 1586056459,
#   'high_temp': 83.37,
#   'humidity': 28,
#   'latitude': 29.54,
#   'longitude': 67.88,
#   'wind': 4.25},
#  {'city': 'bredasdorp',
#   'clouds': 98,
#   'country': 'ZA',
#   'date': 1586056461,
#   'high_temp': 53.6,
#   'humidity': 93,
#   'latitude': -34.53,
#   'longitude': 20.04,
#   'wind': 4.7},
#  {'city': 'payo',
#   'clouds': 73,
#   'country': 'ID',
#   'date': 1586056462,
#   'high_temp': 80.47,
#   'humidity': 84,
#   'latitude': -3.75,
#   'longitude': 103.64,
#   'wind': 1.72},
#  {'city': 'andros town',
#   'clouds': 16,
#   'country': 'BS',
#   'date': 1586056463,
#   'high_temp': 72,
#   'humidity': 73,
#   'latitude': 24.7,
#   'longitude': -77.77,
#   'wind': 2.24},
#  {'city': 'nueva concepcion',
#   'clouds': 18,
#   'country': 'GT',
#   'date': 1586056465,
#   'high_temp': 81.05,
#   'humidity': 73,
#   'latitude': 14.2,
#   'longitude': -91.3,
#   'wind': 5.7},
#  {'city': 'harbour breton',
#   'clouds': 98,
#   'country': 'CA',
#   'date': 1586056466,
#   'high_temp': 30.07,
#   'humidity': 96,
#   'latitude': 47.48,
#   'longitude': -55.8,
#   'wind': 7.58},
#  {'city': 'nanortalik',
#   'clouds': 96,
#   'country': 'GL',
#   'date': 1586056469,
#   'high_temp': 25.68,
#   'humidity': 82,
#   'latitude': 60.14,
#   'longitude': -45.24,
#   'wind': 29.55},
#  {'city': 'purepero',
#   'clouds': 0,
#   'country': 'MX',
#   'date': 1586056471,
#   'high_temp': 60.01,
#   'humidity': 44,
#   'latitude': 19.92,
#   'longitude': -102.02,
#   'wind': 3.8},
#  {'city': 'shar',
#   'clouds': 0,
#   'country': 'KZ',
#   'date': 1586056473,
#   'high_temp': 45.45,
#   'humidity': 64,
#   'latitude': 49.59,
#   'longitude': 81.05,
#   'wind': 3.06},
#  {'city': 'klaksvik',
#   'clouds': 100,
#   'country': 'FO',
#   'date': 1586056475,
#   'high_temp': 44.6,
#   'humidity': 93,
#   'latitude': 62.23,
#   'longitude': -6.59,
#   'wind': 21.92},
#  {'city': 'marabba',
#   'clouds': 6,
#   'country': 'SD',
#   'date': 1586056477,
#   'high_temp': 76.3,
#   'humidity': 14,
#   'latitude': 12.35,
#   'longitude': 32.18,
#   'wind': 6.93},
#  {'city': 'okha',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056479,
#   'high_temp': 29.14,
#   'humidity': 93,
#   'latitude': 53.57,
#   'longitude': 142.95,
#   'wind': 9.24},
#  {'city': 'ilo',
#   'clouds': 99,
#   'country': 'PE',
#   'date': 1586056480,
#   'high_temp': 71.67,
#   'humidity': 76,
#   'latitude': -17.64,
#   'longitude': -71.34,
#   'wind': 2.42},
#  {'city': 'tampa',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056357,
#   'high_temp': 73.4,
#   'humidity': 78,
#   'latitude': 27.95,
#   'longitude': -82.46,
#   'wind': 5.37},
#  {'city': 'cockburn town',
#   'clouds': 0,
#   'country': 'TC',
#   'date': 1586056422,
#   'high_temp': 75.42,
#   'humidity': 60,
#   'latitude': 21.46,
#   'longitude': -71.14,
#   'wind': 10.69},
#  {'city': 'ancud',
#   'clouds': 90,
#   'country': 'CL',
#   'date': 1586056484,
#   'high_temp': 48.2,
#   'humidity': 93,
#   'latitude': -41.87,
#   'longitude': -73.82,
#   'wind': 6.93},
#  {'city': 'whitehorse',
#   'clouds': 75,
#   'country': 'CA',
#   'date': 1586056485,
#   'high_temp': 33.8,
#   'humidity': 37,
#   'latitude': 60.72,
#   'longitude': -135.05,
#   'wind': 2.24},
#  {'city': 'narsaq',
#   'clouds': 100,
#   'country': 'GL',
#   'date': 1586056486,
#   'high_temp': 23,
#   'humidity': 49,
#   'latitude': 60.92,
#   'longitude': -46.05,
#   'wind': 49.44},
#  {'city': 'thinadhoo',
#   'clouds': 100,
#   'country': 'MV',
#   'date': 1586056487,
#   'high_temp': 82.29,
#   'humidity': 72,
#   'latitude': 0.53,
#   'longitude': 72.93,
#   'wind': 2.82},
#  {'city': 'sechura',
#   'clouds': 24,
#   'country': 'PE',
#   'date': 1586056489,
#   'high_temp': 75.16,
#   'humidity': 73,
#   'latitude': -5.56,
#   'longitude': -80.82,
#   'wind': 9.4},
#  {'city': 'atar',
#   'clouds': 0,
#   'country': 'MR',
#   'date': 1586056491,
#   'high_temp': 70.75,
#   'humidity': 27,
#   'latitude': 20.52,
#   'longitude': -13.05,
#   'wind': 5.35},
#  {'city': 'mahebourg',
#   'clouds': 40,
#   'country': 'MU',
#   'date': 1586056493,
#   'high_temp': 77,
#   'humidity': 78,
#   'latitude': -20.41,
#   'longitude': 57.7,
#   'wind': 3.36},
#  {'city': 'pacific grove',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056494,
#   'high_temp': 57.2,
#   'humidity': 82,
#   'latitude': 36.62,
#   'longitude': -121.92,
#   'wind': 9.17},
#  {'city': 'dikson',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056496,
#   'high_temp': 17.37,
#   'humidity': 97,
#   'latitude': 73.51,
#   'longitude': 80.55,
#   'wind': 9.06},
#  {'city': 'cervo',
#   'clouds': 63,
#   'country': 'ES',
#   'date': 1586056497,
#   'high_temp': 56.44,
#   'humidity': 66,
#   'latitude': 43.67,
#   'longitude': -7.41,
#   'wind': 7.85},
#  {'city': 'tiksi',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056498,
#   'high_temp': 9.86,
#   'humidity': 90,
#   'latitude': 71.69,
#   'longitude': 128.87,
#   'wind': 13.98},
#  {'city': 'mazagao',
#   'clouds': 40,
#   'country': 'BR',
#   'date': 1586056500,
#   'high_temp': 82.4,
#   'humidity': 100,
#   'latitude': -0.12,
#   'longitude': -51.29,
#   'wind': 9.17},
#  {'city': 'sioux lookout',
#   'clouds': 20,
#   'country': 'CA',
#   'date': 1586056501,
#   'high_temp': 26.6,
#   'humidity': 85,
#   'latitude': 50.1,
#   'longitude': -91.92,
#   'wind': 4.21},
#  {'city': 'krasnoselkup',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056503,
#   'high_temp': 33.31,
#   'humidity': 94,
#   'latitude': 65.7,
#   'longitude': 82.47,
#   'wind': 21.25},
#  {'city': 'constitucion',
#   'clouds': 30,
#   'country': 'CL',
#   'date': 1586056504,
#   'high_temp': 55.94,
#   'humidity': 57,
#   'latitude': -35.33,
#   'longitude': -72.42,
#   'wind': 8.3},
#  {'city': 'gusau',
#   'clouds': 100,
#   'country': 'NG',
#   'date': 1586056505,
#   'high_temp': 80.11,
#   'humidity': 54,
#   'latitude': 12.16,
#   'longitude': 6.66,
#   'wind': 12.91},
#  {'city': 'kruisfontein',
#   'clouds': 81,
#   'country': 'ZA',
#   'date': 1586056507,
#   'high_temp': 61.88,
#   'humidity': 83,
#   'latitude': -34,
#   'longitude': 24.73,
#   'wind': 8.39},
#  {'city': 'sibolga',
#   'clouds': 100,
#   'country': 'ID',
#   'date': 1586056508,
#   'high_temp': 78.87,
#   'humidity': 81,
#   'latitude': 1.74,
#   'longitude': 98.78,
#   'wind': 4.18},
#  {'city': 'jinzhou',
#   'clouds': 0,
#   'country': 'CN',
#   'date': 1586056509,
#   'high_temp': 52.2,
#   'humidity': 32,
#   'latitude': 41.11,
#   'longitude': 121.14,
#   'wind': 11.77},
#  {'city': 'santa maria',
#   'clouds': 0,
#   'country': 'BR',
#   'date': 1586056511,
#   'high_temp': 59,
#   'humidity': 77,
#   'latitude': -29.68,
#   'longitude': -53.81,
#   'wind': 2.24},
#  {'city': 'poronaysk',
#   'clouds': 94,
#   'country': 'RU',
#   'date': 1586056512,
#   'high_temp': 32.4,
#   'humidity': 94,
#   'latitude': 49.22,
#   'longitude': 143.12,
#   'wind': 12.55},
#  {'city': 'kijang',
#   'clouds': 0,
#   'country': 'KR',
#   'date': 1586056379,
#   'high_temp': 53.6,
#   'humidity': 25,
#   'latitude': 35.24,
#   'longitude': 129.21,
#   'wind': 8.05},
#  {'city': 'avera',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056515,
#   'high_temp': 62.6,
#   'humidity': 63,
#   'latitude': 33.19,
#   'longitude': -82.53,
#   'wind': 3.36},
#  {'city': 'vardo',
#   'clouds': 100,
#   'country': 'NO',
#   'date': 1586056516,
#   'high_temp': 30.15,
#   'humidity': 91,
#   'latitude': 70.37,
#   'longitude': 31.11,
#   'wind': 12.71},
#  {'city': 'mumford',
#   'clouds': 95,
#   'country': 'GH',
#   'date': 1586056330,
#   'high_temp': 80.24,
#   'humidity': 83,
#   'latitude': 5.26,
#   'longitude': -0.76,
#   'wind': 4.36},
#  {'city': 'hami',
#   'clouds': 29,
#   'country': 'CN',
#   'date': 1586056518,
#   'high_temp': 62.29,
#   'humidity': 16,
#   'latitude': 42.8,
#   'longitude': 93.45,
#   'wind': 1.68},
#  {'city': 'la ronge',
#   'clouds': 40,
#   'country': 'CA',
#   'date': 1586056520,
#   'high_temp': 15.8,
#   'humidity': 52,
#   'latitude': 55.1,
#   'longitude': -105.28,
#   'wind': 2.59},
#  {'city': 'lima',
#   'clouds': 0,
#   'country': 'PE',
#   'date': 1586056360,
#   'high_temp': 71.6,
#   'humidity': 83,
#   'latitude': -12.04,
#   'longitude': -77.03,
#   'wind': 12.75},
#  {'city': 'nyurba',
#   'clouds': 16,
#   'country': 'RU',
#   'date': 1586056523,
#   'high_temp': 24.17,
#   'humidity': 94,
#   'latitude': 63.28,
#   'longitude': 118.33,
#   'wind': 9.78},
#  {'city': 'new norfolk',
#   'clouds': 75,
#   'country': 'AU',
#   'date': 1586056525,
#   'high_temp': 51.8,
#   'humidity': 53,
#   'latitude': -42.78,
#   'longitude': 147.06,
#   'wind': 19.46},
#  {'city': 'caala',
#   'clouds': 23,
#   'country': 'AO',
#   'date': 1586056526,
#   'high_temp': 57.67,
#   'humidity': 59,
#   'latitude': -12.85,
#   'longitude': 15.56,
#   'wind': 1.23},
#  {'city': 'guanica',
#   'clouds': 6,
#   'country': 'PR',
#   'date': 1586056527,
#   'high_temp': 79,
#   'humidity': 82,
#   'latitude': 17.97,
#   'longitude': -66.91,
#   'wind': 3.04},
#  {'city': 'sao felix do xingu',
#   'clouds': 99,
#   'country': 'BR',
#   'date': 1586056529,
#   'high_temp': 74.68,
#   'humidity': 88,
#   'latitude': -6.64,
#   'longitude': -51.99,
#   'wind': 0.83},
#  {'city': 'tuktoyaktuk',
#   'clouds': 5,
#   'country': 'CA',
#   'date': 1586056530,
#   'high_temp': 14,
#   'humidity': 72,
#   'latitude': 69.45,
#   'longitude': -133.04,
#   'wind': 13.87},
#  {'city': 'nikolskoye',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056531,
#   'high_temp': 28.4,
#   'humidity': 74,
#   'latitude': 59.7,
#   'longitude': 30.79,
#   'wind': 4.47},
#  {'city': 'avarua',
#   'clouds': 100,
#   'country': 'CK',
#   'date': 1586056533,
#   'high_temp': 82.4,
#   'humidity': 88,
#   'latitude': -21.21,
#   'longitude': -159.78,
#   'wind': 12.75},
#  {'city': 'arraial do cabo',
#   'clouds': 13,
#   'country': 'BR',
#   'date': 1586056534,
#   'high_temp': 75.65,
#   'humidity': 71,
#   'latitude': -22.97,
#   'longitude': -42.03,
#   'wind': 11.36},
#  {'city': 'husavik',
#   'clouds': 90,
#   'country': 'IS',
#   'date': 1586056536,
#   'high_temp': 19.4,
#   'humidity': 79,
#   'latitude': 66.04,
#   'longitude': -17.34,
#   'wind': 43.62},
#  {'city': 'pangkalanbuun',
#   'clouds': 94,
#   'country': 'ID',
#   'date': 1586056504,
#   'high_temp': 82.08,
#   'humidity': 80,
#   'latitude': -2.68,
#   'longitude': 111.62,
#   'wind': 2.21},
#  {'city': 'axim',
#   'clouds': 89,
#   'country': 'GH',
#   'date': 1586056538,
#   'high_temp': 80.53,
#   'humidity': 82,
#   'latitude': 4.87,
#   'longitude': -2.24,
#   'wind': 5.35},
#  {'city': 'kazachinskoye',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056539,
#   'high_temp': 35.78,
#   'humidity': 80,
#   'latitude': 57.7,
#   'longitude': 93.28,
#   'wind': 4.16},
#  {'city': 'airai',
#   'clouds': 11,
#   'country': 'TL',
#   'date': 1586056541,
#   'high_temp': 74.95,
#   'humidity': 45,
#   'latitude': -8.93,
#   'longitude': 125.41,
#   'wind': 2.28},
#  {'city': 'ketchikan',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056354,
#   'high_temp': 42.8,
#   'humidity': 55,
#   'latitude': 55.34,
#   'longitude': -131.65,
#   'wind': 16.11},
#  {'city': 'hithadhoo',
#   'clouds': 98,
#   'country': 'MV',
#   'date': 1586056543,
#   'high_temp': 81.28,
#   'humidity': 79,
#   'latitude': -0.6,
#   'longitude': 73.08,
#   'wind': 9.28},
#  {'city': 'misratah',
#   'clouds': 0,
#   'country': 'LY',
#   'date': 1586056545,
#   'high_temp': 58.51,
#   'humidity': 72,
#   'latitude': 32.38,
#   'longitude': 15.09,
#   'wind': 17.74},
#  {'city': 'nalut',
#   'clouds': 6,
#   'country': 'LY',
#   'date': 1586056546,
#   'high_temp': 49.73,
#   'humidity': 52,
#   'latitude': 30.33,
#   'longitude': 10.85,
#   'wind': 10.83},
#  {'city': 'katima mulilo',
#   'clouds': 89,
#   'country': 'NA',
#   'date': 1586056547,
#   'high_temp': 64.4,
#   'humidity': 100,
#   'latitude': -17.5,
#   'longitude': 24.27,
#   'wind': 2.24},
#  {'city': 'belaya gora',
#   'clouds': 86,
#   'country': 'RU',
#   'date': 1586056548,
#   'high_temp': 10.11,
#   'humidity': 88,
#   'latitude': 68.53,
#   'longitude': 146.42,
#   'wind': 5.12},
#  {'city': 'hualmay',
#   'clouds': 18,
#   'country': 'PE',
#   'date': 1586056551,
#   'high_temp': 71.51,
#   'humidity': 78,
#   'latitude': -11.1,
#   'longitude': -77.61,
#   'wind': 4.88},
#  {'city': 'ostrovnoy',
#   'clouds': 71,
#   'country': 'RU',
#   'date': 1586056552,
#   'high_temp': 21.87,
#   'humidity': 95,
#   'latitude': 68.05,
#   'longitude': 39.51,
#   'wind': 31.12},
#  {'city': 'goundam',
#   'clouds': 0,
#   'country': 'ML',
#   'date': 1586056554,
#   'high_temp': 81.73,
#   'humidity': 14,
#   'latitude': 16.41,
#   'longitude': -3.67,
#   'wind': 8.08},
#  {'city': 'lorengau',
#   'clouds': 51,
#   'country': 'PG',
#   'date': 1586056555,
#   'high_temp': 83.95,
#   'humidity': 74,
#   'latitude': -2.02,
#   'longitude': 147.27,
#   'wind': 9.55},
#  {'city': 'sinnamary',
#   'clouds': 95,
#   'country': 'GF',
#   'date': 1586056556,
#   'high_temp': 80.17,
#   'humidity': 80,
#   'latitude': 5.38,
#   'longitude': -52.95,
#   'wind': 13.78},
#  {'city': 'chernyshevskiy',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056557,
#   'high_temp': 25.84,
#   'humidity': 95,
#   'latitude': 63.01,
#   'longitude': 112.47,
#   'wind': 13.18},
#  {'city': 'huangpi',
#   'clouds': 75,
#   'country': 'CN',
#   'date': 1586056521,
#   'high_temp': 66.2,
#   'humidity': 42,
#   'latitude': 30.88,
#   'longitude': 114.38,
#   'wind': 11.18},
#  {'city': 'ljubinje',
#   'clouds': 97,
#   'country': 'BA',
#   'date': 1586056560,
#   'high_temp': 59,
#   'humidity': 30,
#   'latitude': 42.95,
#   'longitude': 18.09,
#   'wind': 18.34},
#  {'city': 'margate',
#   'clouds': 0,
#   'country': 'GB',
#   'date': 1586056561,
#   'high_temp': 51.01,
#   'humidity': 81,
#   'latitude': 51.38,
#   'longitude': 1.39,
#   'wind': 6.93},
#  {'city': 'martinsville',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056563,
#   'high_temp': 60.8,
#   'humidity': 66,
#   'latitude': 36.69,
#   'longitude': -79.87,
#   'wind': 3.8},
#  {'city': 'rustenburg',
#   'clouds': 1,
#   'country': 'ZA',
#   'date': 1586056564,
#   'high_temp': 55.62,
#   'humidity': 55,
#   'latitude': -25.67,
#   'longitude': 27.24,
#   'wind': 2.71},
#  {'city': 'yar-sale',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056567,
#   'high_temp': 34.5,
#   'humidity': 98,
#   'latitude': 66.83,
#   'longitude': 70.83,
#   'wind': 15.75},
#  {'city': 'puerto ayora',
#   'clouds': 10,
#   'country': 'EC',
#   'date': 1586056568,
#   'high_temp': 80.01,
#   'humidity': 85,
#   'latitude': -0.74,
#   'longitude': -90.35,
#   'wind': 1.99},
#  {'city': 'kavaratti',
#   'clouds': 100,
#   'country': 'IN',
#   'date': 1586056569,
#   'high_temp': 83.16,
#   'humidity': 70,
#   'latitude': 10.57,
#   'longitude': 72.64,
#   'wind': 3.85},
#  {'city': 'businga',
#   'clouds': 7,
#   'country': 'CD',
#   'date': 1586056571,
#   'high_temp': 72.91,
#   'humidity': 77,
#   'latitude': 3.33,
#   'longitude': 20.88,
#   'wind': 2.59},
#  {'city': 'hofn',
#   'clouds': 100,
#   'country': 'IS',
#   'date': 1586056572,
#   'high_temp': 27.64,
#   'humidity': 95,
#   'latitude': 64.25,
#   'longitude': -15.21,
#   'wind': 48.21},
#  {'city': 'tete',
#   'clouds': 1,
#   'country': 'MZ',
#   'date': 1586056573,
#   'high_temp': 66.2,
#   'humidity': 88,
#   'latitude': -16.16,
#   'longitude': 33.59,
#   'wind': 2.35},
#  {'city': 'mao',
#   'clouds': 0,
#   'country': 'ES',
#   'date': 1586056575,
#   'high_temp': 48.2,
#   'humidity': 93,
#   'latitude': 39.89,
#   'longitude': 4.27,
#   'wind': 5.26},
#  {'city': 'betare oya',
#   'clouds': 91,
#   'country': 'CM',
#   'date': 1586056576,
#   'high_temp': 68.83,
#   'humidity': 75,
#   'latitude': 5.6,
#   'longitude': 14.08,
#   'wind': 2.48},
#  {'city': 'khatanga',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056577,
#   'high_temp': 28.42,
#   'humidity': 98,
#   'latitude': 71.97,
#   'longitude': 102.5,
#   'wind': 9.91},
#  {'city': 'puyang',
#   'clouds': 100,
#   'country': 'CN',
#   'date': 1586056578,
#   'high_temp': 57.09,
#   'humidity': 57,
#   'latitude': 29.46,
#   'longitude': 119.89,
#   'wind': 6.62},
#  {'city': 'puerto colombia',
#   'clouds': 75,
#   'country': 'CO',
#   'date': 1586056344,
#   'high_temp': 82.4,
#   'humidity': 83,
#   'latitude': 10.99,
#   'longitude': -74.95,
#   'wind': 18.34},
#  {'city': 'washington',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586056289,
#   'high_temp': 46.4,
#   'humidity': 31,
#   'latitude': 47.5,
#   'longitude': -120.5,
#   'wind': 4.7},
#  {'city': 'sept-iles',
#   'clouds': 5,
#   'country': 'CA',
#   'date': 1586056583,
#   'high_temp': 27,
#   'humidity': 100,
#   'latitude': 50.2,
#   'longitude': -66.38,
#   'wind': 5.84},
#  {'city': 'havoysund',
#   'clouds': 100,
#   'country': 'NO',
#   'date': 1586056585,
#   'high_temp': 24.8,
#   'humidity': 92,
#   'latitude': 71,
#   'longitude': 24.66,
#   'wind': 20.8},
#  {'city': 'acajutiba',
#   'clouds': 22,
#   'country': 'BR',
#   'date': 1586056586,
#   'high_temp': 76.15,
#   'humidity': 90,
#   'latitude': -11.66,
#   'longitude': -38.02,
#   'wind': 7.47},
#  {'city': 'mansa',
#   'clouds': 69,
#   'country': 'IN',
#   'date': 1586056587,
#   'high_temp': 78.31,
#   'humidity': 25,
#   'latitude': 29.98,
#   'longitude': 75.38,
#   'wind': 5.17},
#  {'city': 'altagracia de orituco',
#   'clouds': 89,
#   'country': 'VE',
#   'date': 1586056589,
#   'high_temp': 75.54,
#   'humidity': 73,
#   'latitude': 9.86,
#   'longitude': -66.38,
#   'wind': 3.58},
#  {'city': 'kambove',
#   'clouds': 0,
#   'country': 'CD',
#   'date': 1586056590,
#   'high_temp': 57,
#   'humidity': 62,
#   'latitude': -10.88,
#   'longitude': 26.6,
#   'wind': 2.8},
#  {'city': 'estelle',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586056591,
#   'high_temp': 66.2,
#   'humidity': 93,
#   'latitude': 29.85,
#   'longitude': -90.11,
#   'wind': 3.36},
#  {'city': 'inhambane',
#   'clouds': 16,
#   'country': 'MZ',
#   'date': 1586056593,
#   'high_temp': 72.57,
#   'humidity': 75,
#   'latitude': -23.86,
#   'longitude': 35.38,
#   'wind': 3.38},
#  {'city': 'livenka',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056595,
#   'high_temp': 35.33,
#   'humidity': 78,
#   'latitude': 50.45,
#   'longitude': 38.3,
#   'wind': 6.53},
#  {'city': 'kincardine',
#   'clouds': 72,
#   'country': 'GB',
#   'date': 1586056596,
#   'high_temp': 46.4,
#   'humidity': 75,
#   'latitude': 56.07,
#   'longitude': -3.72,
#   'wind': 4.7},
#  {'city': 'gat',
#   'clouds': 20,
#   'country': 'IL',
#   'date': 1586056598,
#   'high_temp': 80.6,
#   'humidity': 19,
#   'latitude': 31.61,
#   'longitude': 34.76,
#   'wind': 20.8},
#  {'city': 'agadir',
#   'clouds': 75,
#   'country': 'MA',
#   'date': 1586056390,
#   'high_temp': 60.8,
#   'humidity': 87,
#   'latitude': 30.42,
#   'longitude': -9.6,
#   'wind': 2.42},
#  {'city': 'lander',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056550,
#   'high_temp': 37.4,
#   'humidity': 51,
#   'latitude': 42.83,
#   'longitude': -108.73,
#   'wind': 5.82},
#  {'city': 'saquarema',
#   'clouds': 75,
#   'country': 'BR',
#   'date': 1586056601,
#   'high_temp': 75.2,
#   'humidity': 73,
#   'latitude': -22.92,
#   'longitude': -42.51,
#   'wind': 5.82},
#  {'city': 'mildura',
#   'clouds': 90,
#   'country': 'AU',
#   'date': 1586056603,
#   'high_temp': 64.4,
#   'humidity': 59,
#   'latitude': -34.2,
#   'longitude': 142.15,
#   'wind': 13.87},
#  {'city': 'sagua de tanamo',
#   'clouds': 1,
#   'country': 'CU',
#   'date': 1586056604,
#   'high_temp': 68.95,
#   'humidity': 80,
#   'latitude': 20.58,
#   'longitude': -75.24,
#   'wind': 4.34},
#  {'city': 'bosaso',
#   'clouds': 78,
#   'country': 'SO',
#   'date': 1586056605,
#   'high_temp': 79.92,
#   'humidity': 69,
#   'latitude': 11.28,
#   'longitude': 49.18,
#   'wind': 6.24},
#  {'city': 'iqaluit',
#   'clouds': 5,
#   'country': 'CA',
#   'date': 1586056607,
#   'high_temp': -2,
#   'humidity': 76,
#   'latitude': 63.75,
#   'longitude': -68.51,
#   'wind': 21.92},
#  {'city': 'carahue',
#   'clouds': 2,
#   'country': 'CL',
#   'date': 1586056608,
#   'high_temp': 42.8,
#   'humidity': 93,
#   'latitude': -38.7,
#   'longitude': -73.17,
#   'wind': 2.24},
#  {'city': 'poyarkovo',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056609,
#   'high_temp': 40.75,
#   'humidity': 56,
#   'latitude': 49.6,
#   'longitude': 128.68,
#   'wind': 5.39},
#  {'city': 'houma',
#   'clouds': 40,
#   'country': 'US',
#   'date': 1586056428,
#   'high_temp': 64.4,
#   'humidity': 87,
#   'latitude': 29.6,
#   'longitude': -90.72,
#   'wind': 6.93},
#  {'city': 'kapit',
#   'clouds': 71,
#   'country': 'MY',
#   'date': 1586056612,
#   'high_temp': 91.27,
#   'humidity': 56,
#   'latitude': 2.02,
#   'longitude': 112.93,
#   'wind': 2.01},
#  {'city': 'camacha',
#   'clouds': 40,
#   'country': 'PT',
#   'date': 1586056448,
#   'high_temp': 66.2,
#   'humidity': 82,
#   'latitude': 33.08,
#   'longitude': -16.33,
#   'wind': 18.34},
#  {'city': 'mantua',
#   'clouds': 8,
#   'country': 'IT',
#   'date': 1586056614,
#   'high_temp': 51.01,
#   'humidity': 61,
#   'latitude': 45.17,
#   'longitude': 10.78,
#   'wind': 4.7},
#  {'city': 'jacareacanga',
#   'clouds': 78,
#   'country': 'BR',
#   'date': 1586056616,
#   'high_temp': 75.63,
#   'humidity': 91,
#   'latitude': -6.22,
#   'longitude': -57.75,
#   'wind': 1.41},
#  {'city': 'phan thiet',
#   'clouds': 16,
#   'country': 'VN',
#   'date': 1586056617,
#   'high_temp': 90.77,
#   'humidity': 47,
#   'latitude': 10.93,
#   'longitude': 108.1,
#   'wind': 16.06},
#  {'city': 'kaoma',
#   'clouds': 51,
#   'country': 'ZM',
#   'date': 1586056620,
#   'high_temp': 60.4,
#   'humidity': 60,
#   'latitude': -14.78,
#   'longitude': 24.8,
#   'wind': 4.52},
#  {'city': 'hibbing',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056621,
#   'high_temp': 30.2,
#   'humidity': 73,
#   'latitude': 47.43,
#   'longitude': -92.94,
#   'wind': 1.41},
#  {'city': 'bulawayo',
#   'clouds': 78,
#   'country': 'ZW',
#   'date': 1586056623,
#   'high_temp': 59.41,
#   'humidity': 60,
#   'latitude': -20.15,
#   'longitude': 28.58,
#   'wind': 2.86},
#  {'city': 'tiarei',
#   'clouds': 89,
#   'country': 'PF',
#   'date': 1586056624,
#   'high_temp': 87.8,
#   'humidity': 70,
#   'latitude': -17.53,
#   'longitude': -149.33,
#   'wind': 10.29},
#  {'city': 'tasiilaq',
#   'clouds': 2,
#   'country': 'GL',
#   'date': 1586056625,
#   'high_temp': 14,
#   'humidity': 43,
#   'latitude': 65.61,
#   'longitude': -37.64,
#   'wind': 14.99},
#  {'city': 'egvekinot',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056627,
#   'high_temp': 2.16,
#   'humidity': 88,
#   'latitude': 66.32,
#   'longitude': -179.17,
#   'wind': 18.45},
#  {'city': 'la peca',
#   'clouds': 45,
#   'country': 'PE',
#   'date': 1586056629,
#   'high_temp': 68.81,
#   'humidity': 67,
#   'latitude': -5.61,
#   'longitude': -78.44,
#   'wind': 2.62},
#  {'city': 'montepuez',
#   'clouds': 7,
#   'country': 'MZ',
#   'date': 1586056394,
#   'high_temp': 64.9,
#   'humidity': 85,
#   'latitude': -13.13,
#   'longitude': 39,
#   'wind': 3.74},
#  {'city': 'chokurdakh',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056632,
#   'high_temp': 3.9,
#   'humidity': 90,
#   'latitude': 70.63,
#   'longitude': 147.92,
#   'wind': 10.71},
#  {'city': 'limoeiro',
#   'clouds': 40,
#   'country': 'BR',
#   'date': 1586056633,
#   'high_temp': 84.2,
#   'humidity': 79,
#   'latitude': -7.87,
#   'longitude': -35.45,
#   'wind': 3.36},
#  {'city': 'high level',
#   'clouds': 20,
#   'country': 'CA',
#   'date': 1586056634,
#   'high_temp': 23,
#   'humidity': 41,
#   'latitude': 58.52,
#   'longitude': -117.14,
#   'wind': 2.24},
#  {'city': 'xuddur',
#   'clouds': 4,
#   'country': 'SO',
#   'date': 1586056636,
#   'high_temp': 75.22,
#   'humidity': 65,
#   'latitude': 4.12,
#   'longitude': 43.89,
#   'wind': 12.68},
#  {'city': 'pevek',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056638,
#   'high_temp': -0.08,
#   'humidity': 92,
#   'latitude': 69.7,
#   'longitude': 170.31,
#   'wind': 11.16},
#  {'city': 'hambantota',
#   'clouds': 20,
#   'country': 'LK',
#   'date': 1586056640,
#   'high_temp': 82.4,
#   'humidity': 94,
#   'latitude': 6.12,
#   'longitude': 81.12,
#   'wind': 4.7},
#  {'city': 'ranong',
#   'clouds': 20,
#   'country': 'TH',
#   'date': 1586056642,
#   'high_temp': 89.6,
#   'humidity': 62,
#   'latitude': 9.97,
#   'longitude': 98.63,
#   'wind': 4.7},
#  {'city': 'sanmenxia',
#   'clouds': 85,
#   'country': 'CN',
#   'date': 1586056643,
#   'high_temp': 64.31,
#   'humidity': 26,
#   'latitude': 34.77,
#   'longitude': 111.18,
#   'wind': 8.88},
#  {'city': 'lata',
#   'clouds': 40,
#   'country': 'PT',
#   'date': 1586056644,
#   'high_temp': 59,
#   'humidity': 82,
#   'latitude': 40.16,
#   'longitude': -8.33,
#   'wind': 16.11},
#  {'city': 'niquero',
#   'clouds': 12,
#   'country': 'CU',
#   'date': 1586056646,
#   'high_temp': 74.91,
#   'humidity': 73,
#   'latitude': 20.04,
#   'longitude': -77.58,
#   'wind': 10.13},
#  {'city': 'berkovica',
#   'clouds': 87,
#   'country': 'BA',
#   'date': 1586056647,
# ...
#   'humidity': 80,
#   'latitude': 23.17,
#   'longitude': -97.95,
#   'wind': 5.3},
#  {'city': 'jumla',
#   'clouds': 0,
#   'country': 'NP',
#   'date': 1586056968,
#   'high_temp': 54.09,
#   'humidity': 15,
#   'latitude': 29.27,
#   'longitude': 82.18,
#   'wind': 2.35},
#  {'city': 'tromso',
#   'clouds': 75,
#   'country': 'NO',
#   'date': 1586056970,
#   'high_temp': 24.8,
#   'humidity': 79,
#   'latitude': 69.65,
#   'longitude': 18.96,
#   'wind': 16.11},
#  {'city': 'baculin',
#   'clouds': 38,
#   'country': 'PH',
#   'date': 1586056971,
#   'high_temp': 85.55,
#   'humidity': 60,
#   'latitude': 7.45,
#   'longitude': 126.58,
#   'wind': 9.24},
#  {'city': 'warmbad',
#   'clouds': 34,
#   'country': 'NA',
#   'date': 1586056972,
#   'high_temp': 69.46,
#   'humidity': 25,
#   'latitude': -28.45,
#   'longitude': 18.73,
#   'wind': 9.4},
#  {'city': 'ulladulla',
#   'clouds': 10,
#   'country': 'AU',
#   'date': 1586056974,
#   'high_temp': 72,
#   'humidity': 34,
#   'latitude': -35.35,
#   'longitude': 150.47,
#   'wind': 24.16},
#  {'city': 'stykkisholmur',
#   'clouds': 100,
#   'country': 'IS',
#   'date': 1586056975,
#   'high_temp': 22.08,
#   'humidity': 90,
#   'latitude': 65.08,
#   'longitude': -22.73,
#   'wind': 47},
#  {'city': 'joshimath',
#   'clouds': 0,
#   'country': 'IN',
#   'date': 1586056976,
#   'high_temp': 55.04,
#   'humidity': 15,
#   'latitude': 30.57,
#   'longitude': 79.57,
#   'wind': 2.55},
#  {'city': 'vitim',
#   'clouds': 82,
#   'country': 'RU',
#   'date': 1586056977,
#   'high_temp': 29.93,
#   'humidity': 92,
#   'latitude': 59.45,
#   'longitude': 112.56,
#   'wind': 11.14},
#  {'city': 'antananarivo',
#   'clouds': 40,
#   'country': 'MG',
#   'date': 1586056686,
#   'high_temp': 59,
#   'humidity': 87,
#   'latitude': -18.91,
#   'longitude': 47.54,
#   'wind': 5.82},
#  {'city': 'talavera de la reina',
#   'clouds': 81,
#   'country': 'ES',
#   'date': 1586056980,
#   'high_temp': 51.89,
#   'humidity': 67,
#   'latitude': 39.96,
#   'longitude': -4.83,
#   'wind': 1.97},
#  {'city': 'namatanai',
#   'clouds': 3,
#   'country': 'PG',
#   'date': 1586056788,
#   'high_temp': 83.71,
#   'humidity': 69,
#   'latitude': -3.67,
#   'longitude': 152.43,
#   'wind': 7.63},
#  {'city': 'salisbury',
#   'clouds': 0,
#   'country': 'GB',
#   'date': 1586056959,
#   'high_temp': 51.01,
#   'humidity': 81,
#   'latitude': 51.07,
#   'longitude': -1.8,
#   'wind': 11.41},
#  {'city': 'shasta lake',
#   'clouds': 90,
#   'country': 'US',
#   'date': 1586056984,
#   'high_temp': 46,
#   'humidity': 93,
#   'latitude': 40.68,
#   'longitude': -122.37,
#   'wind': 4.7},
#  {'city': 'changping',
#   'clouds': 47,
#   'country': 'CN',
#   'date': 1586056985,
#   'high_temp': 55.4,
#   'humidity': 30,
#   'latitude': 40.22,
#   'longitude': 116.22,
#   'wind': 6.71},
#  {'city': 'beringovskiy',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056986,
#   'high_temp': 6.15,
#   'humidity': 93,
#   'latitude': 63.05,
#   'longitude': 179.32,
#   'wind': 26.8},
#  {'city': 'ramshir',
#   'clouds': 35,
#   'country': 'IR',
#   'date': 1586056987,
#   'high_temp': 64.4,
#   'humidity': 68,
#   'latitude': 30.89,
#   'longitude': 49.41,
#   'wind': 7.38},
#  {'city': 'kondinskoye',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586056989,
#   'high_temp': 37.24,
#   'humidity': 96,
#   'latitude': 59.65,
#   'longitude': 67.41,
#   'wind': 11.65},
#  {'city': 'alvorada',
#   'clouds': 0,
#   'country': 'BR',
#   'date': 1586056990,
#   'high_temp': 75.52,
#   'humidity': 72,
#   'latitude': -12.48,
#   'longitude': -49.12,
#   'wind': 2.08},
#  {'city': 'isiro',
#   'clouds': 92,
#   'country': 'CD',
#   'date': 1586056991,
#   'high_temp': 67.08,
#   'humidity': 79,
#   'latitude': 2.77,
#   'longitude': 27.62,
#   'wind': 1.9},
#  {'city': 'ampanihy',
#   'clouds': 100,
#   'country': 'MG',
#   'date': 1586056993,
#   'high_temp': 68.2,
#   'humidity': 77,
#   'latitude': -24.7,
#   'longitude': 44.75,
#   'wind': 9.28},
#  {'city': 'atherton',
#   'clouds': 0,
#   'country': 'GB',
#   'date': 1586056994,
#   'high_temp': 50,
#   'humidity': 53,
#   'latitude': 53.52,
#   'longitude': -2.49,
#   'wind': 8.05},
#  {'city': 'bokoro',
#   'clouds': 57,
#   'country': 'TD',
#   'date': 1586056995,
#   'high_temp': 86.92,
#   'humidity': 30,
#   'latitude': 12.38,
#   'longitude': 17.06,
#   'wind': 6.71},
#  {'city': 'nogliki',
#   'clouds': 0,
#   'country': 'RU',
#   'date': 1586056996,
#   'high_temp': 29.61,
#   'humidity': 94,
#   'latitude': 51.83,
#   'longitude': 143.17,
#   'wind': 11.45},
#  {'city': 'mahina',
#   'clouds': 95,
#   'country': 'PF',
#   'date': 1586056998,
#   'high_temp': 87.8,
#   'humidity': 70,
#   'latitude': -17.51,
#   'longitude': -149.49,
#   'wind': 10.29},
#  {'city': 'abashiri',
#   'clouds': 75,
#   'country': 'JP',
#   'date': 1586056999,
#   'high_temp': 39.2,
#   'humidity': 93,
#   'latitude': 44.02,
#   'longitude': 144.27,
#   'wind': 9.17},
#  {'city': 'selcuk',
#   'clouds': 75,
#   'country': 'TR',
#   'date': 1586057000,
#   'high_temp': 62.6,
#   'humidity': 100,
#   'latitude': 37.95,
#   'longitude': 27.37,
#   'wind': 12.75},
#  {'city': 'maceio',
#   'clouds': 98,
#   'country': 'BR',
#   'date': 1586057001,
#   'high_temp': 77,
#   'humidity': 100,
#   'latitude': -9.67,
#   'longitude': -35.74,
#   'wind': 3.36},
#  {'city': 'cascais',
#   'clouds': 40,
#   'country': 'PT',
#   'date': 1586057003,
#   'high_temp': 61,
#   'humidity': 82,
#   'latitude': 38.7,
#   'longitude': -9.42,
#   'wind': 14.99},
#  {'city': 'castelo',
#   'clouds': 99,
#   'country': 'BR',
#   'date': 1586057004,
#   'high_temp': 69.71,
#   'humidity': 76,
#   'latitude': -20.6,
#   'longitude': -41.18,
#   'wind': 1.72},
#  {'city': 'rondonopolis',
#   'clouds': 3,
#   'country': 'BR',
#   'date': 1586057005,
#   'high_temp': 74.48,
#   'humidity': 88,
#   'latitude': -16.47,
#   'longitude': -54.64,
#   'wind': 1.72},
#  {'city': 'jalu',
#   'clouds': 6,
#   'country': 'LY',
#   'date': 1586057006,
#   'high_temp': 59.18,
#   'humidity': 72,
#   'latitude': 29.03,
#   'longitude': 21.55,
#   'wind': 11.81},
#  {'city': 'mathbaria',
#   'clouds': 0,
#   'country': 'BD',
#   'date': 1586057008,
#   'high_temp': 87.15,
#   'humidity': 55,
#   'latitude': 22.29,
#   'longitude': 89.96,
#   'wind': 1.57},
#  {'city': 'saravan',
#   'clouds': 40,
#   'country': 'AM',
#   'date': 1586057009,
#   'high_temp': 37.4,
#   'humidity': 93,
#   'latitude': 39.72,
#   'longitude': 45.65,
#   'wind': 6.93},
#  {'city': 'klyuchi',
#   'clouds': 4,
#   'country': 'RU',
#   'date': 1586057010,
#   'high_temp': 37.22,
#   'humidity': 74,
#   'latitude': 52.27,
#   'longitude': 79.17,
#   'wind': 10.89},
#  {'city': 'bay roberts',
#   'clouds': 90,
#   'country': 'CA',
#   'date': 1586057011,
#   'high_temp': 28,
#   'humidity': 92,
#   'latitude': 47.6,
#   'longitude': -53.26,
#   'wind': 8.05},
#  {'city': 'nieuw nickerie',
#   'clouds': 95,
#   'country': 'SR',
#   'date': 1586057013,
#   'high_temp': 80.28,
#   'humidity': 82,
#   'latitude': 5.95,
#   'longitude': -56.98,
#   'wind': 14.18},
#  {'city': 'vega de alatorre',
#   'clouds': 99,
#   'country': 'MX',
#   'date': 1586056865,
#   'high_temp': 79.54,
#   'humidity': 84,
#   'latitude': 20.03,
#   'longitude': -96.63,
#   'wind': 4.7},
#  {'city': 'mareeba',
#   'clouds': 9,
#   'country': 'AU',
#   'date': 1586057015,
#   'high_temp': 89.01,
#   'humidity': 70,
#   'latitude': -17,
#   'longitude': 145.43,
#   'wind': 10.29},
#  {'city': 'komsomolsk',
#   'clouds': 0,
#   'country': 'UA',
#   'date': 1586057017,
#   'high_temp': 39.38,
#   'humidity': 65,
#   'latitude': 49.01,
#   'longitude': 33.65,
#   'wind': 4.61},
#  {'city': 'caxito',
#   'clouds': 75,
#   'country': 'AO',
#   'date': 1586057018,
#   'high_temp': 80.6,
#   'humidity': 88,
#   'latitude': -8.58,
#   'longitude': 13.66,
#   'wind': 5.82},
#  {'city': 'samarai',
#   'clouds': 47,
#   'country': 'PG',
#   'date': 1586057020,
#   'high_temp': 84.7,
#   'humidity': 63,
#   'latitude': -10.62,
#   'longitude': 150.67,
#   'wind': 14.23},
#  {'city': 'kenai',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586057022,
#   'high_temp': 35.6,
#   'humidity': 80,
#   'latitude': 60.55,
#   'longitude': -151.26,
#   'wind': 6.93},
#  {'city': 'kinsale',
#   'clouds': 75,
#   'country': 'IE',
#   'date': 1586057023,
#   'high_temp': 48.99,
#   'humidity': 81,
#   'latitude': 51.71,
#   'longitude': -8.53,
#   'wind': 18.34},
#  {'city': 'sirur',
#   'clouds': 15,
#   'country': 'IN',
#   'date': 1586057024,
#   'high_temp': 87.1,
#   'humidity': 16,
#   'latitude': 18.83,
#   'longitude': 74.38,
#   'wind': 7.18},
#  {'city': 'panaba',
#   'clouds': 0,
#   'country': 'MX',
#   'date': 1586057025,
#   'high_temp': 77.18,
#   'humidity': 69,
#   'latitude': 21.28,
#   'longitude': -88.27,
#   'wind': 10.49},
#  {'city': 'potsdam',
#   'clouds': 0,
#   'country': 'DE',
#   'date': 1586057002,
#   'high_temp': 41,
#   'humidity': 56,
#   'latitude': 52.4,
#   'longitude': 13.07,
#   'wind': 5.82},
#  {'city': 'maralal',
#   'clouds': 0,
#   'country': 'KE',
#   'date': 1586057028,
#   'high_temp': 59.67,
#   'humidity': 52,
#   'latitude': 1.1,
#   'longitude': 36.7,
#   'wind': 4.92},
#  {'city': 'batsfjord',
#   'clouds': 100,
#   'country': 'NO',
#   'date': 1586057029,
#   'high_temp': 26.35,
#   'humidity': 93,
#   'latitude': 70.63,
#   'longitude': 29.72,
#   'wind': 13.27},
#  {'city': 'lerwick',
#   'clouds': 100,
#   'country': 'GB',
#   'date': 1586057031,
#   'high_temp': 46.4,
#   'humidity': 81,
#   'latitude': 60.15,
#   'longitude': -1.15,
#   'wind': 12.75},
#  {'city': 'asau',
#   'clouds': 83,
#   'country': 'RO',
#   'date': 1586057032,
#   'high_temp': 43,
#   'humidity': 52,
#   'latitude': 46.43,
#   'longitude': 26.4,
#   'wind': 11.41},
#  {'city': 'labrea',
#   'clouds': 100,
#   'country': 'BR',
#   'date': 1586057033,
#   'high_temp': 75.18,
#   'humidity': 90,
#   'latitude': -7.26,
#   'longitude': -64.8,
#   'wind': 1.57},
#  {'city': 'suntar',
#   'clouds': 98,
#   'country': 'RU',
#   'date': 1586057035,
#   'high_temp': 26.4,
#   'humidity': 93,
#   'latitude': 62.14,
#   'longitude': 117.63,
#   'wind': 11.03},
#  {'city': 'svetlogorsk',
#   'clouds': 0,
#   'country': 'BY',
#   'date': 1586056869,
#   'high_temp': 31.93,
#   'humidity': 88,
#   'latitude': 52.63,
#   'longitude': 29.73,
#   'wind': 8.19},
#  {'city': 'ambunti',
#   'clouds': 49,
#   'country': 'PG',
#   'date': 1586057037,
#   'high_temp': 91.26,
#   'humidity': 56,
#   'latitude': -4.24,
#   'longitude': 142.84,
#   'wind': 3.56},
#  {'city': 'sopo',
#   'clouds': 20,
#   'country': 'CO',
#   'date': 1586057038,
#   'high_temp': 55.4,
#   'humidity': 82,
#   'latitude': 4.91,
#   'longitude': -73.94,
#   'wind': 4.7},
#  {'city': 'severomuysk',
#   'clouds': 85,
#   'country': 'RU',
#   'date': 1586057040,
#   'high_temp': 16.3,
#   'humidity': 74,
#   'latitude': 56.15,
#   'longitude': 113.43,
#   'wind': 8.41},
#  {'city': 'the valley',
#   'clouds': 0,
#   'country': 'AI',
#   'date': 1586057041,
#   'high_temp': 79,
#   'humidity': 74,
#   'latitude': 18.22,
#   'longitude': -63.06,
#   'wind': 2.24},
#  {'city': 'kattivakkam',
#   'clouds': 40,
#   'country': 'IN',
#   'date': 1586057042,
#   'high_temp': 86,
#   'humidity': 74,
#   'latitude': 13.22,
#   'longitude': 80.32,
#   'wind': 4.7},
#  {'city': 'gornopravdinsk',
#   'clouds': 100,
#   'country': 'RU',
#   'date': 1586057043,
#   'high_temp': 35.29,
#   'humidity': 91,
#   'latitude': 60.05,
#   'longitude': 69.9,
#   'wind': 11.23},
#  {'city': 'raahe',
#   'clouds': 0,
#   'country': 'FI',
#   'date': 1586057045,
#   'high_temp': 23,
#   'humidity': 67,
#   'latitude': 64.68,
#   'longitude': 24.48,
#   'wind': 9.17},
#  {'city': 'roald',
#   'clouds': 100,
#   'country': 'NO',
#   'date': 1586057046,
#   'high_temp': 37,
#   'humidity': 95,
#   'latitude': 62.58,
#   'longitude': 6.13,
#   'wind': 16.11},
#  {'city': 'pilar',
#   'clouds': 98,
#   'country': 'BR',
#   'date': 1586057047,
#   'high_temp': 77,
#   'humidity': 100,
#   'latitude': -9.6,
#   'longitude': -35.96,
#   'wind': 3.36},
#  {'city': 'koumac',
#   'clouds': 34,
#   'country': 'NC',
#   'date': 1586057049,
#   'high_temp': 84.07,
#   'humidity': 66,
#   'latitude': -20.57,
#   'longitude': 164.28,
#   'wind': 15.03},
#  {'city': 'petropavlovsk-kamchatskiy',
#   'clouds': 59,
#   'country': 'RU',
#   'date': 1586057050,
#   'high_temp': 37.4,
#   'humidity': 32,
#   'latitude': 53.05,
#   'longitude': 158.65,
#   'wind': 8.95},
#  {'city': 'brae',
#   'clouds': 100,
#   'country': 'GB',
#   'date': 1586057051,
#   'high_temp': 46.4,
#   'humidity': 87,
#   'latitude': 60.4,
#   'longitude': -1.35,
#   'wind': 13.87},
#  {'city': 'guisa',
#   'clouds': 20,
#   'country': 'CU',
#   'date': 1586057053,
#   'high_temp': 71.6,
#   'humidity': 78,
#   'latitude': 20.25,
#   'longitude': -76.54,
#   'wind': 9.17},
#  {'city': 'launceston',
#   'clouds': 75,
#   'country': 'AU',
#   'date': 1586057054,
#   'high_temp': 54,
#   'humidity': 81,
#   'latitude': -41.45,
#   'longitude': 147.17,
#   'wind': 12.75},
#  {'city': 'kununurra',
#   'clouds': 40,
#   'country': 'AU',
#   'date': 1586057055,
#   'high_temp': 95,
#   'humidity': 50,
#   'latitude': -15.77,
#   'longitude': 128.73,
#   'wind': 4.7},
#  {'city': 'mersing',
#   'clouds': 40,
#   'country': 'MY',
#   'date': 1586057056,
#   'high_temp': 91.4,
#   'humidity': 70,
#   'latitude': 2.43,
#   'longitude': 103.84,
#   'wind': 6.93},
#  {'city': 'darovskoy',
#   'clouds': 4,
#   'country': 'RU',
#   'date': 1586057058,
#   'high_temp': 27.07,
#   'humidity': 96,
#   'latitude': 58.77,
#   'longitude': 47.96,
#   'wind': 8.37},
#  {'city': 'kaeo',
#   'clouds': 42,
#   'country': 'NZ',
#   'date': 1586057059,
#   'high_temp': 70,
#   'humidity': 54,
#   'latitude': -35.1,
#   'longitude': 173.78,
#   'wind': 10},
#  {'city': 'rulenge',
#   'clouds': 83,
#   'country': 'TZ',
#   'date': 1586057060,
#   'high_temp': 60.28,
#   'humidity': 63,
#   'latitude': -2.72,
#   'longitude': 30.63,
#   'wind': 1.72},
#  {'city': 'vao',
#   'clouds': 15,
#   'country': 'NC',
#   'date': 1586057061,
#   'high_temp': 78.03,
#   'humidity': 79,
#   'latitude': -22.67,
#   'longitude': 167.48,
#   'wind': 21.34},
#  {'city': 'wilmington',
#   'clouds': 1,
#   'country': 'US',
#   'date': 1586056972,
#   'high_temp': 61,
#   'humidity': 76,
#   'latitude': 34.23,
#   'longitude': -77.94,
#   'wind': 8.05},
#  {'city': 'hasanabad',
#   'clouds': 7,
#   'country': 'IR',
#   'date': 1586057064,
#   'high_temp': 57.2,
#   'humidity': 87,
#   'latitude': 36.55,
#   'longitude': 61.05,
#   'wind': 2.24},
#  {'city': 'bilibino',
#   'clouds': 96,
#   'country': 'RU',
#   'date': 1586057067,
#   'high_temp': -3.53,
#   'humidity': 80,
#   'latitude': 68.05,
#   'longitude': 166.44,
#   'wind': 2.48},
#  {'city': 'smithers',
#   'clouds': 5,
#   'country': 'CA',
#   'date': 1586056987,
#   'high_temp': 35.6,
#   'humidity': 31,
#   'latitude': 54.78,
#   'longitude': -127.17,
#   'wind': 4.7},
#  {'city': 'de aar',
#   'clouds': 0,
#   'country': 'ZA',
#   'date': 1586057069,
#   'high_temp': 61.88,
#   'humidity': 37,
#   'latitude': -30.65,
#   'longitude': 24.01,
#   'wind': 7.45},
#  {'city': 'willmar',
#   'clouds': 75,
#   'country': 'US',
#   'date': 1586057070,
#   'high_temp': 39.2,
#   'humidity': 74,
#   'latitude': 45.12,
#   'longitude': -95.04,
#   'wind': 6.93},
#  {'city': 'paine',
#   'clouds': 100,
#   'country': 'CL',
#   'date': 1586057072,
#   'high_temp': 60.8,
#   'humidity': 67,
#   'latitude': -33.82,
#   'longitude': -70.75,
#   'wind': 6.93},
#  {'city': 'raudeberg',
#   'clouds': 100,
#   'country': 'NO',
#   'date': 1586057074,
#   'high_temp': 41,
#   'humidity': 93,
#   'latitude': 61.99,
#   'longitude': 5.14,
#   'wind': 13.87},
#  {'city': 'lasa',
#   'clouds': 5,
#   'country': 'IT',
#   'date': 1586057075,
#   'high_temp': 42.01,
#   'humidity': 51,
#   'latitude': 46.62,
#   'longitude': 10.7,
#   'wind': 5.82},
#  {'city': 'savannah bight',
#   'clouds': 0,
#   'country': 'HN',
#   'date': 1586057077,
#   'high_temp': 80.6,
#   'humidity': 82,
#   'latitude': 16.45,
#   'longitude': -85.85,
#   'wind': 25.03},
#  {'city': 'geraldton',
#   'clouds': 54,
#   'country': 'AU',
#   'date': 1586057078,
#   'high_temp': 84.2,
#   'humidity': 35,
#   'latitude': -28.77,
#   'longitude': 114.6,
#   'wind': 6.93},
#  {'city': 'pochutla',
#   'clouds': 37,
#   'country': 'MX',
#   'date': 1586057080,
#   'high_temp': 80.01,
#   'humidity': 76,
#   'latitude': 15.74,
#   'longitude': -96.47,
#   'wind': 6.42},
#  {'city': 'vallenar',
#   'clouds': 98,
#   'country': 'CL',
#   'date': 1586057081,
#   'high_temp': 68.7,
#   'humidity': 44,
#   'latitude': -28.57,
#   'longitude': -70.76,
#   'wind': 0.36},
#  {'city': 'nantucket',
#   'clouds': 20,
#   'country': 'US',
#   'date': 1586057082,
#   'high_temp': 39.99,
#   'humidity': 93,
#   'latitude': 41.28,
#   'longitude': -70.1,
#   'wind': 5.82},
#  {'city': 'sola',
#   'clouds': 90,
#   'country': 'VU',
#   'date': 1586057084,
#   'high_temp': 80.6,
#   'humidity': 94,
#   'latitude': -13.88,
#   'longitude': 167.55,
#   'wind': 32.61},
#  {'city': 'villa carlos paz',
#   'clouds': 86,
#   'country': 'AR',
#   'date': 1586057085,
#   'high_temp': 69.01,
#   'humidity': 77,
#   'latitude': -31.42,
#   'longitude': -64.5,
#   'wind': 10.29}]

# %%
cities_data_df = pd.DataFrame()

# %%
cities_data_df = pd.DataFrame.from_dict(cities_data, orient='columns')

# %%
cities_data_df
# Out:
#                    city  clouds country        date  high_temp  humidity  \
# 0                  lebu       0      CL  1586056262      54.43        75
# 1               biltine      97      TD  1586056264      84.00        13
# 2              saldanha      81      ZA  1586056265      57.20        93
# 3                 vaini      75      TO  1586056267      78.80        69
# 4    havre-saint-pierre      90      CA  1586056269      30.20        92
# ..                  ...     ...     ...         ...        ...       ...
# 579            pochutla      37      MX  1586057080      80.01        76
# 580            vallenar      98      CL  1586057081      68.70        44
# 581           nantucket      20      US  1586057082      39.99        93
# 582                sola      90      VU  1586057084      80.60        94
# 583    villa carlos paz      86      AR  1586057085      69.01        77
#
#      latitude  longitude   wind
# 0      -37.62     -73.65  14.79
# 1       14.53      20.92   8.61
# 2      -33.01      17.94   6.93
# 3      -21.20    -175.20   8.05
# 4       50.23     -63.60   2.24
# ..        ...        ...    ...
# 579     15.74     -96.47   6.42
# 580    -28.57     -70.76   0.36
# 581     41.28     -70.10   5.82
# 582    -13.88     167.55  32.61
# 583    -31.42     -64.50  10.29
#
# [584 rows x 9 columns]

# %%
#save so i can go to bed its 2:24am lmao. finish tomorrow
cities_data_df.to_csv('cities_data_df.csv', index = False, header=True)

# %%
cities_data_df.head()
# Out:
#                  city  clouds country        date  high_temp  humidity  \
# 0                lebu       0      CL  1586056262      54.43        75
# 1             biltine      97      TD  1586056264      84.00        13
# 2            saldanha      81      ZA  1586056265      57.20        93
# 3               vaini      75      TO  1586056267      78.80        69
# 4  havre-saint-pierre      90      CA  1586056269      30.20        92
#
#    latitude  longitude   wind
# 0    -37.62     -73.65  14.79
# 1     14.53      20.92   8.61
# 2    -33.01      17.94   6.93
# 3    -21.20    -175.20   8.05
# 4     50.23     -63.60   2.24

# %%
#plot 1: latitude vs temperature

plt.scatter(cities_data_df['latitude'], cities_data_df['high_temp'], edgecolor='blue', marker='o', alpha=.5)

plt.title('City Latitude vs Max Temperature (%s)' % time.strftime('%x'))
plt.ylabel('Max Temp (F)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('City_lat_vs_temp.png')

plt.show()

# %%
#plot 2: Latitude & Humidity

plt.scatter(cities_data_df['latitude'], cities_data_df['humidity'], edgecolor='blue', marker='o', alpha=.5)

plt.title('City Latitude vs Humidity (%s)' % time.strftime('%x'))
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('City_lat_vs_humidity.png')

plt.show()

# %%
#plot 3: latitude vs cloudiness

plt.scatter(cities_data_df['latitude'], cities_data_df['clouds'], edgecolor='blue', marker='o', alpha=.5)

plt.title('City Latitude vs Cloudiness (%s)' % time.strftime('%x'))
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('City_lat_vs_clouds.png')

plt.show()

# %%
#plot 4: latitude vs wind speed

plt.scatter(cities_data_df['latitude'], cities_data_df['wind'], edgecolor='blue', marker='o', alpha=.5)

plt.title('City Latitude vs Wind Speed (%s)' % time.strftime('%x'))
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('City_lat_vs_wind.png')

plt.show()

# %%
#make the linear regression function - did this in group project :)

def linreg_plot(x_values, y_values, title, )
